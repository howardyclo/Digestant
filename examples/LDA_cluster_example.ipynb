# %% [markdown]
# ## Import packages

# %%
import sys

# %%
sys.path.append('../data_helpers/')
sys.path.append('../preprocess')
sys.path.append('../cluster/')

# %%
from twitter_data_helper import TwitterDataHelper
from text_cleaner import TextCleaner
from lda_cluster import LDACluster
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Get data

# %%
data_helper = TwitterDataHelper()
df = data_helper.get_data(['2017-07-05', '2017-07-06', '2017-07-07', '2017-07-08', '2017-07-09', '2017-07-10'])

# %%
df
# Out:
#       source           created_at           author  \
# 0    twitter  2017-07-07 21:17:08     jakewarrentx
# 1    twitter  2017-07-10 16:08:09      stanfordnlp
# 2    twitter  2017-07-06 20:58:52      stanfordnlp
# 3    twitter  2017-07-06 20:50:16      stanfordnlp
# 4    twitter  2017-07-05 15:41:02             ncsc
# 5    twitter  2017-07-05 14:26:03             ncsc
# 6    twitter  2017-07-05 14:00:46             ncsc
# 7    twitter  2017-07-05 12:30:38             ncsc
# 8    twitter  2017-07-05 11:07:02             ncsc
# 9    twitter  2017-07-05 10:01:26             ncsc
# 10   twitter  2017-07-05 08:56:03             ncsc
# 11   twitter  2017-07-05 08:30:04             ncsc
# 12   twitter  2017-07-05 07:55:03             ncsc
# 13   twitter  2017-07-05 07:48:03             ncsc
# 14   twitter  2017-07-07 14:07:02             ncsc
# 15   twitter  2017-07-07 13:45:03             ncsc
# 16   twitter  2017-07-07 13:11:04             ncsc
# 17   twitter  2017-07-07 12:31:03             ncsc
# 18   twitter  2017-07-07 10:54:02             ncsc
# 19   twitter  2017-07-07 10:07:02             ncsc
# 20   twitter  2017-07-07 08:10:03             ncsc
# 21   twitter  2017-07-10 14:48:03             ncsc
# 22   twitter  2017-07-10 13:15:03             ncsc
# 23   twitter  2017-07-10 11:41:02             ncsc
# 24   twitter  2017-07-10 10:02:02             ncsc
# 25   twitter  2017-07-10 08:46:03             ncsc
# 26   twitter  2017-07-06 16:22:03             ncsc
# 27   twitter  2017-07-06 14:17:03             ncsc
# 28   twitter  2017-07-06 12:05:03             ncsc
# 29   twitter  2017-07-06 10:24:02             ncsc
# ..       ...                  ...              ...
# 848  twitter  2017-07-06 15:11:10          mxlearn
# 849  twitter  2017-07-06 15:11:09          mxlearn
# 850  twitter  2017-07-06 14:39:11          mxlearn
# 851  twitter  2017-07-06 10:20:06          mxlearn
# 852  twitter  2017-07-08 17:17:03       olesovhcom
# 853  twitter  2017-07-08 16:41:28       olesovhcom
# 854  twitter  2017-07-05 11:13:53      JAMESWT_MHT
# 855  twitter  2017-07-07 14:11:48      JAMESWT_MHT
# 856  twitter  2017-07-06 20:15:55      JAMESWT_MHT
# 857  twitter  2017-07-06 13:39:00      JAMESWT_MHT
# 858  twitter  2017-07-06 11:59:59      JAMESWT_MHT
# 859  twitter  2017-07-05 17:47:17  MalwareTechBlog
# 860  twitter  2017-07-05 08:53:59  MalwareTechBlog
# 861  twitter  2017-07-08 16:42:29  MalwareTechBlog
# 862  twitter  2017-07-08 08:43:31  MalwareTechBlog
# 863  twitter  2017-07-07 16:06:50  MalwareTechBlog
# 864  twitter  2017-07-07 10:11:41  MalwareTechBlog
# 865  twitter  2017-07-10 12:08:31  MalwareTechBlog
# 866  twitter  2017-07-06 12:07:08  MalwareTechBlog
# 867  twitter  2017-07-06 10:37:53  MalwareTechBlog
# 868  twitter  2017-07-06 10:07:00  MalwareTechBlog
# 869  twitter  2017-07-06 08:37:00  MalwareTechBlog
# 870  twitter  2017-07-05 23:03:34          kchonyc
# 871  twitter  2017-07-05 02:56:00          kchonyc
# 872  twitter  2017-07-07 07:51:44          kchonyc
# 873  twitter  2017-07-10 06:25:52          kchonyc
# 874  twitter  2017-07-10 02:33:42          kchonyc
# 875  twitter  2017-07-06 08:37:16          kchonyc
# 876  twitter  2017-07-05 21:00:35        bartblaze
# 877  twitter  2017-07-06 11:14:01        bartblaze
#
#                                                   text  \
# 0    Wow. This is the second time in two weeks they...
# 1    This is a lovely use of our new CoreNLP server...
# 2    SNLI—https://t.co/Ybc3Z2RXLM—good for general ...
# 3    Our news summary: #NLProc DyNet sneaking into ...
# 4    Did you hear Chris Ensor on #R4Today discussin...
# 5    Our shiny, new Chrome OS guidance. Tap into ou...
# 6    Meet one girl who impressed our team so much s...
# 7    How's everyone getting on? If you've cracked o...
# 8    See how implementing our #passwordguidance hel...
# 9    John Humphrys called it ‘baffling’, but can yo...
# 10   We've rolled out free &amp; easy steps to imme...
# 11   John Humphrys called it ‘baffling’, but can yo...
# 12   This morning Chris Ensor was on #R4Today discu...
# 13   Trailblazing teen Kim was on #R4Today talking ...
# 14   Our four Active Cyber Defence programmes will ...
# 15   Congratulations if you worked out our 'bafflin...
# 16   Our 10 steps to cyber security https://t.co/SS...
# 17   Ever wondered if that 'free wi-fi' hotspot is ...
# 18   Guidance in action! Improving mobile users exp...
# 19   Did you know that data from a breach is often ...
# 20   Do you know what a DoS attack is? https://t.co...
# 21   Ransomware has hit the headlines heavily recen...
# 22   Does our Secure by Default Partnership Program...
# 23   This week's Threat Report: scams follow widely...
# 24   What is the #phishing threat following a data ...
# 25   What's new with our Windows End User Device Gu...
# 26   Historic hack of LinkedIn in 2012: what you ne...
# 27   Why we're working to make our assurance proces...
# 28   What are the core concepts of risk management ...
# 29   How simplifying their logon processes transfor...
# ..                                                 ...
# 848  [N] AI and Machine Learning in the future of a...
# 849  [P] Evaluation code for various automated metr...
# 850  [R] Main recommendation system algorithms and ...
# 851  [R] [1707.01083] ShuffleNet: An Extremely Effi...
# 852  94 .ch &amp; .li domain names hijacked and use...
# 853  Because #Ovh strategy is to "Be Global", we wi...
# 854  #malware from #spam https://t.co/QPIL3o6lFi ht...
# 855  #pdf #phishing FUD Detection ratio:0 / 57\nsul...
# 856  For my friend @Antelox :P \n #URLZone (aka #Sh...
# 857  #blackshades NET #rat First submission  ( 6 ye...
# 858  #hta #downloader from #dhl #spam mail\nhttps:/...
# 859  Pretty sure there's people you can hire for th...
# 860  "Why does Windows let you encrypt files?!?!?" ...
# 861  I saw a thread during the last major bitcoin c...
# 862  Petya "Wiper" might be decryptable after all h...
# 863  Threat Attribution in 2017 https://t.co/BcTsPE...
# 864  I googled "Homemade Dynamite" (Lorde song) and...
# 865  Solar panels in the UK 😂😂😂 https://t.co/mZaTxc...
# 866  I'd say no that's fucking ridiculous but... pu...
# 867  In news which should surprise no one. https://...
# 868  If their loss estimates are anything like thei...
# 869  heh, our Jellyfish Apocalypse made the news\nh...
# 870  now the question is... who would want to reloc...
# 871  remember classes are never separate https://t....
# 872  Slides at https://t.co/40r8mNSLLm https://t.co...
# 873  'Comfort women': Researchers claim first known...
# 874                 I like PPO https://t.co/w3Wm4i3FiY
# 875  my comment/question was "it looks like it's no...
# 876  Women in Tech Speak Frankly on Culture of Hara...
# 877  Interesting: VirusTotal += MAX, an AV engine f...
#
#                                               raw_data
# 0    Status(in_reply_to_screen_name=None, place=Non...
# 1    Status(in_reply_to_screen_name=None, place=Non...
# 2    Status(in_reply_to_screen_name=None, place=Non...
# 3    Status(in_reply_to_screen_name=None, place=Non...
# 4    Status(in_reply_to_screen_name=None, place=Non...
# 5    Status(in_reply_to_screen_name=None, place=Non...
# 6    Status(in_reply_to_screen_name=None, place=Non...
# 7    Status(in_reply_to_screen_name=None, place=Non...
# 8    Status(in_reply_to_screen_name=None, place=Non...
# 9    Status(in_reply_to_screen_name=None, place=Non...
# 10   Status(in_reply_to_screen_name=None, place=Non...
# 11   Status(in_reply_to_screen_name=None, place=Non...
# 12   Status(in_reply_to_screen_name=None, place=Non...
# 13   Status(in_reply_to_screen_name=None, place=Non...
# 14   Status(in_reply_to_screen_name=None, place=Non...
# 15   Status(in_reply_to_screen_name=None, place=Non...
# 16   Status(in_reply_to_screen_name=None, place=Non...
# 17   Status(in_reply_to_screen_name=None, place=Non...
# 18   Status(in_reply_to_screen_name=None, place=Non...
# 19   Status(in_reply_to_screen_name=None, place=Non...
# 20   Status(in_reply_to_screen_name=None, place=Non...
# 21   Status(in_reply_to_screen_name=None, place=Non...
# 22   Status(in_reply_to_screen_name=None, place=Non...
# 23   Status(in_reply_to_screen_name=None, place=Non...
# 24   Status(in_reply_to_screen_name=None, place=Non...
# 25   Status(in_reply_to_screen_name=None, place=Non...
# 26   Status(in_reply_to_screen_name=None, place=Non...
# 27   Status(in_reply_to_screen_name=None, place=Non...
# 28   Status(in_reply_to_screen_name=None, place=Non...
# 29   Status(in_reply_to_screen_name=None, place=Non...
# ..                                                 ...
# 848  Status(in_reply_to_screen_name=None, place=Non...
# 849  Status(in_reply_to_screen_name=None, place=Non...
# 850  Status(in_reply_to_screen_name=None, place=Non...
# 851  Status(in_reply_to_screen_name=None, place=Non...
# 852  Status(in_reply_to_screen_name=None, place=Non...
# 853  Status(in_reply_to_screen_name=None, place=Non...
# 854  Status(in_reply_to_screen_name=None, place=Non...
# 855  Status(in_reply_to_screen_name=None, place=Non...
# 856  Status(in_reply_to_screen_name=None, place=Non...
# 857  Status(in_reply_to_screen_name=None, place=Non...
# 858  Status(in_reply_to_screen_name=None, place=Non...
# 859  Status(in_reply_to_screen_name=None, place=Non...
# 860  Status(in_reply_to_screen_name=None, place=Non...
# 861  Status(in_reply_to_screen_name=None, place=Non...
# 862  Status(in_reply_to_screen_name=None, place=Non...
# 863  Status(in_reply_to_screen_name=None, place=Non...
# 864  Status(in_reply_to_screen_name=None, place=Non...
# 865  Status(in_reply_to_screen_name=None, place=Non...
# 866  Status(in_reply_to_screen_name=None, place=Non...
# 867  Status(in_reply_to_screen_name=None, place=Non...
# 868  Status(in_reply_to_screen_name=None, place=Non...
# 869  Status(in_reply_to_screen_name=None, place=Non...
# 870  Status(in_reply_to_screen_name=None, place=Non...
# 871  Status(in_reply_to_screen_name=None, place=Non...
# 872  Status(in_reply_to_screen_name=None, place=Non...
# 873  Status(in_reply_to_screen_name=None, place=Non...
# 874  Status(in_reply_to_screen_name=None, place=Non...
# 875  Status(in_reply_to_screen_name=None, place=Non...
# 876  Status(in_reply_to_screen_name=None, place=Non...
# 877  Status(in_reply_to_screen_name=None, place=Non...
#
# [878 rows x 5 columns]

# %% [markdown]
# ## Get text from data

# %%
texts = df['text']

# %%
len(texts)
# Out:
# 878

# %% [markdown]
# ## Clean text

# %%
text_cleaner = TextCleaner(filter_sentiment_words=True)
# Out:
# * [TextCleaner] Initializing...
# * [TextCleaner] Loading SpaCy "en_core_web_md" corpus...
# * [TextCleaner] Loading stopwords...
# * [TextCleaner] Loading sentinent words...
# --------------------------------------------------------------------------------------------------------------------

# %%
docs = text_cleaner.clean(texts)
# Out:
# 0it [00:00, ?it/s]
# * [TextCleaner] Cleaning text...
# 878it [00:00, 1337.14it/s]

# %% [markdown]
# ## Let's cluster text
#
# ### First, train your LDA. Once model is trained, feature vectors and cluster labels of training data is stored.

# %%
cluster = LDACluster(num_topics=100)

# %%
cluster.fit(docs)
# Out:
# * [LDA] Training model...

# %% [markdown]
# ## Get feature vectors and cluster labels

# %%
df['feature_vector'] = [feature_vector for feature_vector in cluster.feature_vectors]

# %%
df['cluster'] = cluster.labels

# %% [markdown]
# ## Observe topics

# %%
for i in range(cluster.model.num_topics):
    print('Topic {}'.format(i))
    print(cluster.model.print_topic(i))
    print()
# Out:
# Topic 0
# 0.063*"neural" + 0.063*"machine" + 0.063*"translation" + 0.063*"machine_translation" + 0.063*"single" + 0.063*"queue" + 0.063*"decoding_neural" + 0.063*"single_queue" + 0.063*"decoding" + 0.013*"content"
#
# Topic 1
# 0.032*"author" + 0.030*"make" + 0.015*"amp" + 0.015*"learn" + 0.015*"datum" + 0.015*"really" + 0.015*"update" + 0.015*"could" + 0.015*"brain" + 0.015*"today"
#
# Topic 2
# 0.040*"networks" + 0.040*"test" + 0.040*"slide" + 0.021*"amp" + 0.021*"neural" + 0.020*"ransomware" + 0.020*"end" + 0.020*"public" + 0.020*"small" + 0.020*"study"
#
# Topic 3
# 0.026*"get" + 0.014*"new" + 0.013*"security" + 0.013*"make" + 0.013*"word" + 0.013*"approach" + 0.013*"show" + 0.013*"really" + 0.013*"detail" + 0.013*"find"
#
# Topic 4
# 0.035*"symantec" + 0.035*"pxe" + 0.019*"use" + 0.018*"amp" + 0.018*"learning" + 0.018*"know" + 0.018*"petya" + 0.018*"still" + 0.018*"enable" + 0.018*"variant"
#
# Topic 5
# 0.050*"sequence" + 0.046*"author" + 0.037*"lesson" + 0.025*"language" + 0.025*"copy" + 0.025*"models" + 0.025*"enriched" + 0.025*"using" + 0.025*"shakespeariz" + 0.013*"new"
#
# Topic 6
# 0.053*"translation" + 0.053*"multimodal" + 0.053*"imagination" + 0.022*"author" + 0.019*"new" + 0.018*"malware" + 0.018*"file" + 0.018*"target" + 0.018*"video" + 0.018*"av"
#
# Topic 7
# 0.039*"amp" + 0.039*"july" + 0.019*"detail" + 0.019*"join" + 0.019*"last" + 0.019*"art" + 0.019*"pm" + 0.012*"author" + 0.010*"ransomware" + 0.010*"open"
#
# Topic 8
# 0.149*"open" + 0.098*"open_source" + 0.096*"source" + 0.022*"first" + 0.022*"nomination" + 0.022*"szor" + 0.022*"fourth" + 0.022*"peter" + 0.021*"baidu" + 0.018*"tool"
#
# Topic 9
# 0.024*"ai" + 0.024*"report" + 0.024*"future" + 0.015*"machine" + 0.013*"amp" + 0.012*"learn" + 0.012*"make" + 0.012*"look" + 0.012*"datum" + 0.012*"get"
#
# Topic 10
# 0.026*"show" + 0.026*"read" + 0.026*"example" + 0.026*"morning" + 0.016*"author" + 0.013*"write" + 0.013*"people" + 0.013*"day" + 0.013*"memory" + 0.013*"also"
#
# Topic 11
# 0.080*"learning" + 0.070*"deep_learning" + 0.067*"deep" + 0.028*"gan" + 0.028*"brain" + 0.028*"name" + 0.010*"use" + 0.010*"get" + 0.010*"next" + 0.010*"paper"
#
# Topic 12
# 0.071*"author" + 0.043*"programming" + 0.033*"see" + 0.022*"give" + 0.022*"bitcoin" + 0.012*"amp" + 0.011*"word" + 0.011*"campaign" + 0.011*"public" + 0.011*"small"
#
# Topic 13
# 0.026*"author" + 0.024*"emergence" + 0.024*"behaviours" + 0.024*"environments" + 0.024*"locomotion" + 0.017*"use" + 0.016*"code" + 0.016*"really" + 0.016*"deepmind" + 0.016*"want"
#
# Topic 14
# 0.043*"web" + 0.028*"instead" + 0.015*"open" + 0.015*"code" + 0.014*"people" + 0.014*"year" + 0.014*"week" + 0.014*"first" + 0.014*"report" + 0.014*"source"
#
# Topic 15
# 0.075*"dual" + 0.060*"learning" + 0.060*"supervised" + 0.031*"learn" + 0.018*"author" + 0.016*"use" + 0.016*"deep" + 0.015*"paper" + 0.015*"model" + 0.015*"task"
#
# Topic 16
# 0.091*"download" + 0.061*"xls" + 0.051*"urlzone" + 0.051*"attach" + 0.051*"question" + 0.049*"malware" + 0.041*"file" + 0.041*"enable" + 0.041*"bebloh" + 0.041*"macro"
#
# Topic 17
# 0.063*"task" + 0.063*"sigmorphon" + 0.063*"morphological" + 0.063*"morphological_reinflection" + 0.063*"shared" + 0.063*"reinflection" + 0.062*"copy" + 0.057*"uzh" + 0.057*"shared_task" + 0.057*"align"
#
# Topic 18
# 0.032*"bot" + 0.032*"create" + 0.021*"news" + 0.021*"wosign" + 0.021*"attribution" + 0.011*"amp" + 0.011*"malware" + 0.011*"make" + 0.011*"datum" + 0.011*"write"
#
# Topic 19
# 0.031*"try" + 0.023*"author" + 0.021*"car" + 0.021*"wgan" + 0.012*"source" + 0.011*"learning" + 0.011*"learn" + 0.011*"deep" + 0.011*"security" + 0.011*"code"
#
# Topic 20
# 0.050*"author" + 0.033*"comment" + 0.033*"teach" + 0.032*"experience" + 0.017*"ai" + 0.017*"write" + 0.017*"approach" + 0.017*"mobile" + 0.017*"also" + 0.017*"deepmind"
#
# Topic 21
# 0.026*"author" + 0.021*"time" + 0.021*"research" + 0.021*"year" + 0.021*"move" + 0.021*"survey" + 0.021*"project" + 0.021*"solar" + 0.021*"student" + 0.021*"development"
#
# Topic 22
# 0.038*"use" + 0.038*"learn" + 0.037*"attention" + 0.037*"answer" + 0.037*"view" + 0.037*"local" + 0.037*"global" + 0.037*"mechanism" + 0.037*"combine" + 0.037*"selection"
#
# Topic 23
# 0.019*"datum" + 0.019*"target" + 0.019*"chip" + 0.019*"rhel" + 0.012*"author" + 0.010*"amp" + 0.010*"ransomware" + 0.010*"machine" + 0.010*"code" + 0.010*"tool"
#
# Topic 24
# 0.027*"another" + 0.027*"kit" + 0.024*"possible" + 0.014*"people" + 0.014*"approach" + 0.014*"week" + 0.014*"think" + 0.014*"update" + 0.014*"try" + 0.014*"go"
#
# Topic 25
# 0.140*"language" + 0.105*"natural_language" + 0.105*"natural" + 0.090*"generation" + 0.081*"automatic" + 0.081*"explanations" + 0.081*"automatic_generation" + 0.011*"author" + 0.009*"also" + 0.009*"unit"
#
# Topic 26
# 0.065*"author" + 0.025*"vs" + 0.014*"use" + 0.013*"amp" + 0.013*"security" + 0.013*"look" + 0.013*"ai" + 0.013*"people" + 0.013*"software" + 0.013*"impact"
#
# Topic 27
# 0.063*"embedding" + 0.063*"document" + 0.063*"context_aware" + 0.063*"document_embedding" + 0.063*"context" + 0.063*"aware" + 0.025*"author" + 0.024*"science" + 0.016*"datum" + 0.016*"people"
#
# Topic 28
# 0.043*"write" + 0.026*"author" + 0.022*"day" + 0.022*"system" + 0.022*"take" + 0.022*"world" + 0.022*"via" + 0.022*"challenge" + 0.022*"high" + 0.022*"ticket"
#
# Topic 29
# 0.030*"author" + 0.027*"library" + 0.015*"use" + 0.014*"generation" + 0.014*"make" + 0.014*"base" + 0.014*"network" + 0.014*"know" + 0.014*"write" + 0.014*"take"
#
# Topic 30
# 0.027*"author" + 0.025*"security" + 0.024*"victim" + 0.013*"language" + 0.012*"year" + 0.012*"update" + 0.012*"service" + 0.012*"task" + 0.012*"cyber" + 0.012*"game"
#
# Topic 31
# 0.029*"neural" + 0.029*"network" + 0.029*"neural_network" + 0.029*"learns" + 0.029*"physics" + 0.029*"fluids" + 0.015*"new" + 0.015*"day" + 0.015*"know" + 0.015*"networks"
#
# Topic 32
# 0.056*"tool" + 0.052*"natural_language" + 0.052*"natural" + 0.052*"language" + 0.050*"text" + 0.050*"clinical" + 0.050*"interactive" + 0.050*"interactive_tool" + 0.050*"processing_clinical" + 0.050*"processing"
#
# Topic 33
# 0.033*"use" + 0.033*"amp" + 0.032*"windows" + 0.022*"people" + 0.022*"feature" + 0.022*"cryptocurrencie" + 0.022*"depth" + 0.022*"countermeasure" + 0.013*"author" + 0.011*"neural"
#
# Topic 34
# 0.022*"much" + 0.015*"amp" + 0.014*"ai" + 0.014*"day" + 0.014*"really" + 0.014*"process" + 0.014*"take" + 0.014*"impact" + 0.014*"see" + 0.014*"user"
#
# Topic 35
# 0.056*"ai" + 0.043*"people" + 0.042*"pair" + 0.028*"research" + 0.028*"piece" + 0.028*"way" + 0.015*"learn" + 0.015*"make" + 0.015*"look" + 0.014*"impact"
#
# Topic 36
# 0.048*"machine" + 0.045*"neural" + 0.044*"translation" + 0.044*"word" + 0.044*"machine_translation" + 0.044*"visual" + 0.044*"embeddings" + 0.044*"multimodal" + 0.044*"visually" + 0.044*"features"
#
# Topic 37
# 0.024*"ransomware" + 0.019*"amp" + 0.018*"tool" + 0.018*"affect" + 0.015*"btcware" + 0.011*"malware" + 0.009*"base" + 0.009*"machine" + 0.009*"datum" + 0.009*"get"
#
# Topic 38
# 0.036*"go" + 0.036*"come" + 0.036*"way" + 0.018*"security" + 0.018*"year" + 0.018*"software" + 0.018*"still" + 0.018*"join" + 0.018*"let" + 0.018*"speak"
#
# Topic 39
# 0.030*"malware" + 0.029*"next" + 0.029*"system" + 0.029*"gen" + 0.029*"product" + 0.015*"base" + 0.015*"datum" + 0.015*"think" + 0.015*"target" + 0.015*"call"
#
# Topic 40
# 0.078*"documentation" + 0.052*"code" + 0.032*"author" + 0.026*"generation" + 0.026*"function" + 0.026*"example" + 0.026*"python" + 0.026*"automate" + 0.026*"parallel" + 0.026*"string"
#
# Topic 41
# 0.038*"malspam" + 0.025*"malware" + 0.025*"yes" + 0.014*"use" + 0.013*"download" + 0.013*"deep" + 0.013*"time" + 0.013*"tool" + 0.013*"know" + 0.013*"research"
#
# Topic 42
# 0.052*"learn" + 0.051*"behavior" + 0.051*"human" + 0.051*"capture" + 0.051*"imitation" + 0.051*"motion" + 0.021*"author" + 0.018*"new" + 0.017*"research" + 0.017*"deepmind"
#
# Topic 43
# 0.036*"ransomware" + 0.024*"old" + 0.024*"help" + 0.024*"everyone" + 0.015*"software" + 0.013*"open" + 0.012*"learn" + 0.012*"security" + 0.012*"base" + 0.012*"people"
#
# Topic 44
# 0.029*"use" + 0.029*"neural" + 0.028*"network" + 0.028*"neural_network" + 0.028*"claim" + 0.028*"competition" + 0.028*"recognition" + 0.028*"gesture" + 0.028*"convolution" + 0.028*"identification"
#
# Topic 45
# 0.026*"program" + 0.026*"watch" + 0.016*"author" + 0.013*"make" + 0.013*"look" + 0.013*"datum" + 0.013*"time" + 0.013*"network" + 0.013*"really" + 0.013*"find"
#
# Topic 46
# 0.045*"help" + 0.034*"learning" + 0.023*"ransomware" + 0.023*"deep" + 0.023*"deep_learning" + 0.023*"let" + 0.022*"attacker" + 0.022*"spread" + 0.022*"submission" + 0.022*"keras"
#
# Topic 47
# 0.063*"day" + 0.033*"call" + 0.032*"puzzle" + 0.022*"news" + 0.022*"woman" + 0.022*"researcher" + 0.022*"algorithms" + 0.022*"john" + 0.022*"humphrys" + 0.022*"show"
#
# Topic 48
# 0.020*"text" + 0.020*"impact" + 0.020*"sentiment" + 0.020*"feature" + 0.020*"tensorflow" + 0.020*"index" + 0.020*"analyze" + 0.020*"propose" + 0.020*"citation" + 0.020*"determine"
#
# Topic 49
# 0.023*"author" + 0.019*"report" + 0.019*"someone" + 0.019*"go" + 0.019*"notpetya" + 0.019*"say" + 0.019*"speak" + 0.019*"change" + 0.019*"offer" + 0.019*"password"
#
# Topic 50
# 0.076*"machine_learning" + 0.075*"learning" + 0.070*"machine" + 0.028*"algorithms" + 0.028*"tech" + 0.019*"base" + 0.019*"code" + 0.018*"meet" + 0.018*"woman" + 0.018*"rule"
#
# Topic 51
# 0.034*"author" + 0.031*"next" + 0.031*"application" + 0.031*"internship" + 0.017*"use" + 0.016*"new" + 0.016*"neural" + 0.016*"malware" + 0.016*"open" + 0.016*"network"
#
# Topic 52
# 0.052*"adgholas" + 0.042*"outbreak" + 0.042*"thrive" + 0.032*"ransomware" + 0.031*"malvertis" + 0.031*"shadow" + 0.021*"security" + 0.021*"cyber" + 0.021*"dimension" + 0.021*"aim"
#
# Topic 53
# 0.019*"campaign" + 0.019*"detail" + 0.019*"petya" + 0.019*"find" + 0.019*"attention" + 0.019*"target" + 0.019*"service" + 0.019*"notpetya" + 0.019*"old" + 0.019*"way"
#
# Topic 54
# 0.025*"amp" + 0.025*"update" + 0.025*"late" + 0.013*"new" + 0.013*"ransomware" + 0.013*"ai" + 0.013*"tool" + 0.012*"people" + 0.012*"really" + 0.012*"thank"
#
# Topic 55
# 0.045*"variant" + 0.032*"use" + 0.020*"new" + 0.019*"author" + 0.018*"ransomware" + 0.017*"slocker" + 0.016*"mobile" + 0.016*"paper" + 0.016*"also" + 0.016*"happen"
#
# Topic 56
# 0.026*"do" + 0.018*"time" + 0.018*"enable" + 0.018*"feature" + 0.018*"training" + 0.018*"vs" + 0.018*"sentence" + 0.018*"gpu" + 0.018*"cost" + 0.009*"use"
#
# Topic 57
# 0.044*"semantic" + 0.044*"segmentation" + 0.034*"pytorch" + 0.025*"deep" + 0.024*"use" + 0.023*"learn" + 0.023*"language" + 0.023*"code" + 0.023*"networks" + 0.023*"year"
#
# Topic 58
# 0.070*"cross" + 0.070*"image" + 0.070*"similarity" + 0.070*"description" + 0.070*"cross_linguistic" + 0.070*"image_description" + 0.070*"difference" + 0.070*"difference_similarity" + 0.070*"linguistic" + 0.016*"working"
#
# Topic 59
# 0.033*"author" + 0.030*"ai" + 0.030*"hire" + 0.015*"learning" + 0.015*"learn" + 0.015*"people" + 0.015*"first" + 0.015*"another" + 0.015*"deepmind" + 0.015*"user"
#
# Topic 60
# 0.064*"ransomware" + 0.064*"wannacry" + 0.063*"slocker" + 0.052*"mobile" + 0.027*"android" + 0.026*"mimicking" + 0.026*"starts" + 0.024*"new" + 0.014*"amp" + 0.014*"malware"
#
# Topic 61
# 0.146*"author" + 0.057*"software" + 0.045*"developer" + 0.045*"programmer" + 0.031*"target" + 0.030*"line" + 0.030*"businessprocesscompromise" + 0.018*"game" + 0.015*"dialogue" + 0.015*"search"
#
# Topic 62
# 0.027*"attempt" + 0.014*"use" + 0.014*"make" + 0.014*"time" + 0.013*"networks" + 0.013*"detail" + 0.013*"file" + 0.013*"memory" + 0.013*"thank" + 0.013*"happen"
#
# Topic 63
# 0.023*"malware" + 0.023*"security" + 0.022*"medical" + 0.022*"roulette" + 0.014*"author" + 0.012*"use" + 0.012*"ransomware" + 0.012*"amp" + 0.012*"new" + 0.011*"get"
#
# Topic 64
# 0.054*"author" + 0.051*"code" + 0.041*"text" + 0.041*"metric" + 0.041*"media" + 0.041*"social" + 0.041*"mixed" + 0.041*"complexity" + 0.020*"one" + 0.020*"interviews"
#
# Topic 65
# 0.026*"blog" + 0.018*"use" + 0.018*"new" + 0.017*"week" + 0.017*"thank" + 0.017*"post" + 0.017*"try" + 0.009*"get" + 0.009*"day" + 0.009*"year"
#
# Topic 66
# 0.041*"base" + 0.041*"symantec" + 0.028*"new" + 0.027*"time" + 0.027*"race" + 0.027*"cybersecurity" + 0.027*"rely" + 0.014*"amp" + 0.014*"report" + 0.014*"world"
#
# Topic 67
# 0.021*"author" + 0.017*"datum" + 0.017*"get" + 0.017*"network" + 0.017*"day" + 0.017*"next" + 0.017*"attention" + 0.017*"thank" + 0.017*"happen" + 0.017*"sentiment"
#
# Topic 68
# 0.063*"cross" + 0.063*"sentiment" + 0.063*"cross_lingual" + 0.063*"lingual" + 0.056*"translation" + 0.056*"analysis" + 0.056*"without" + 0.056*"without_translation" + 0.056*"sentiment_analysis" + 0.006*"code"
#
# Topic 69
# 0.019*"security" + 0.010*"use" + 0.010*"ransomware" + 0.010*"make" + 0.010*"ai" + 0.010*"write" + 0.010*"research" + 0.010*"semantic" + 0.010*"software" + 0.010*"find"
#
# Topic 70
# 0.031*"author" + 0.028*"file" + 0.028*"another" + 0.028*"api" + 0.015*"use" + 0.015*"learn" + 0.014*"open" + 0.014*"text" + 0.014*"get" + 0.014*"code"
#
# Topic 71
# 0.031*"range" + 0.019*"author" + 0.016*"look" + 0.016*"show" + 0.016*"detail" + 0.016*"attention" + 0.016*"go" + 0.016*"study" + 0.016*"classification" + 0.016*"unit"
#
# Topic 72
# 0.073*"learning" + 0.073*"deep" + 0.073*"base" + 0.073*"word" + 0.073*"prediction" + 0.073*"embedded" + 0.073*"embedded_deep" + 0.073*"learning_base" + 0.073*"word_prediction" + 0.011*"author"
#
# Topic 73
# 0.022*"make" + 0.022*"look" + 0.021*"world" + 0.021*"cyber" + 0.021*"mean" + 0.021*"build" + 0.021*"recent" + 0.021*"bitcoin" + 0.021*"pay" + 0.021*"seven"
#
# Topic 74
# 0.024*"new" + 0.023*"look" + 0.023*"server" + 0.023*"review" + 0.023*"offer" + 0.023*"fi" + 0.023*"wi" + 0.023*"birthday" + 0.023*"fact" + 0.023*"gtx"
#
# Topic 75
# 0.031*"via" + 0.030*"learn" + 0.030*"interface" + 0.017*"wannacry" + 0.017*"slocker" + 0.016*"use" + 0.016*"learning" + 0.016*"security" + 0.016*"get" + 0.016*"networks"
#
# Topic 76
# 0.025*"new" + 0.025*"neural" + 0.025*"ransomware" + 0.015*"author" + 0.013*"use" + 0.013*"malware" + 0.013*"make" + 0.013*"datum" + 0.012*"write" + 0.012*"year"
#
# Topic 77
# 0.033*"time" + 0.033*"one" + 0.033*"touch" + 0.018*"use" + 0.017*"amp" + 0.016*"show" + 0.016*"mean" + 0.016*"hack" + 0.016*"infosec" + 0.016*"drive"
#
# Topic 78
# 0.056*"model" + 0.029*"neural" + 0.028*"language" + 0.028*"attention" + 0.028*"tutor" + 0.028*"computational" + 0.028*"feedback" + 0.028*"acquisition" + 0.028*"grammatical" + 0.028*"hybrid"
#
# Topic 79
# 0.043*"attention" + 0.043*"implementation" + 0.043*"ne" + 0.043*"pytorch" + 0.029*"could" + 0.015*"amp" + 0.015*"new" + 0.015*"neural" + 0.015*"networks" + 0.015*"paper"
#
# Topic 80
# 0.036*"text" + 0.036*"survey" + 0.036*"every" + 0.036*"brief" + 0.036*"technique" + 0.036*"summarization" + 0.024*"time" + 0.024*"year" + 0.024*"would" + 0.024*"function"
#
# Topic 81
# 0.037*"cyber" + 0.037*"discuss" + 0.037*"skill" + 0.037*"ensor" + 0.037*"interest" + 0.037*"chris" + 0.019*"know" + 0.019*"gan" + 0.019*"ne" + 0.019*"hear"
#
# Topic 82
# 0.057*"neural" + 0.057*"language" + 0.057*"generation" + 0.057*"base" + 0.057*"semantic" + 0.057*"dialogue" + 0.057*"spoken_dialogue" + 0.057*"base_neural" + 0.057*"systems" + 0.057*"spoken"
#
# Topic 83
# 0.121*"new" + 0.107*"various" + 0.066*"mobile" + 0.054*"phishing" + 0.054*"pro" + 0.054*"open" + 0.027*"thank" + 0.015*"use" + 0.014*"datum" + 0.014*"know"
#
# Topic 84
# 0.136*"end" + 0.085*"new" + 0.071*"dataset" + 0.071*"dataset_new" + 0.065*"generation" + 0.065*"end_generation" + 0.065*"challenges_end" + 0.065*"challenges" + 0.010*"ai" + 0.007*"amp"
#
# Topic 85
# 0.103*"variational" + 0.094*"generation" + 0.094*"framework" + 0.094*"conditional" + 0.094*"conditional_variational" + 0.094*"framework_dialog" + 0.094*"dialog" + 0.010*"make" + 0.010*"image" + 0.010*"someone"
#
# Topic 86
# 0.029*"learning" + 0.021*"author" + 0.019*"code" + 0.019*"dialogue" + 0.019*"notpetya" + 0.019*"supervised" + 0.019*"sample" + 0.019*"data" + 0.019*"actor" + 0.019*"management"
#
# Topic 87
# 0.019*"author" + 0.017*"use" + 0.016*"year" + 0.016*"next" + 0.016*"analysis" + 0.016*"service" + 0.016*"memory" + 0.016*"yet" + 0.016*"back" + 0.016*"build"
#
# Topic 88
# 0.065*"change" + 0.034*"strategy" + 0.021*"author" + 0.019*"use" + 0.018*"malware" + 0.018*"look" + 0.017*"tool" + 0.017*"embedding" + 0.017*"process" + 0.017*"service"
#
# Topic 89
# 0.044*"use" + 0.043*"back" + 0.043*"induction" + 0.043*"event" + 0.043*"schema" + 0.043*"factorization" + 0.043*"tensor" + 0.029*"history" + 0.029*"mt" + 0.018*"author"
#
# Topic 90
# 0.057*"learn" + 0.057*"simple" + 0.052*"word" + 0.052*"embedding" + 0.052*"approach" + 0.052*"learn_polysemous" + 0.052*"word_embedding" + 0.052*"polysemous" + 0.052*"simple_approach" + 0.012*"email"
#
# Topic 91
# 0.045*"generate" + 0.023*"base" + 0.023*"datum" + 0.023*"get" + 0.023*"copy" + 0.023*"gan" + 0.023*"without" + 0.023*"clinical" + 0.023*"want" + 0.023*"train"
#
# Topic 92
# 0.033*"ever" + 0.033*"decrypt" + 0.018*"use" + 0.016*"year" + 0.016*"file" + 0.016*"thank" + 0.016*"another" + 0.016*"post" + 0.016*"user" + 0.016*"still"
#
# Topic 93
# 0.022*"learn" + 0.022*"know" + 0.022*"paper" + 0.022*"think" + 0.022*"read" + 0.013*"author" + 0.012*"wannacry" + 0.011*"new" + 0.011*"security" + 0.011*"look"
#
# Topic 94
# 0.025*"security" + 0.025*"write" + 0.025*"android" + 0.025*"july" + 0.025*"zip" + 0.025*"bulletin" + 0.015*"author" + 0.013*"new" + 0.013*"malware" + 0.012*"next"
#
# Topic 95
# 0.037*"guide" + 0.020*"amp" + 0.020*"new" + 0.019*"look" + 0.019*"approach" + 0.019*"week" + 0.019*"first" + 0.019*"high" + 0.019*"search" + 0.019*"manage"
#
# Topic 96
# 0.076*"visual" + 0.071*"deep" + 0.068*"text" + 0.068*"network" + 0.068*"behavior" + 0.068*"composition_behavior" + 0.068*"visual_text" + 0.068*"deep_network" + 0.068*"composition" + 0.012*"much"
#
# Topic 97
# 0.043*"networks" + 0.042*"recurrent" + 0.029*"neural" + 0.028*"small" + 0.028*"convolutional" + 0.028*"footprint" + 0.028*"keyword" + 0.028*"spotting" + 0.015*"malware" + 0.015*"make"
#
# Topic 98
# 0.073*"time" + 0.060*"author" + 0.033*"use" + 0.032*"campaign" + 0.016*"look" + 0.016*"next" + 0.016*"software" + 0.016*"android" + 0.016*"back" + 0.016*"would"
#
# Topic 99
# 0.027*"impact" + 0.014*"amp" + 0.014*"learning" + 0.014*"ransomware" + 0.014*"get" + 0.013*"wannacry" + 0.013*"day" + 0.013*"software" + 0.013*"update" + 0.013*"service"

# %% [markdown]
# ## Show frequent topic words

# %%
import operator
from collections import defaultdict

word_freq = defaultdict(lambda: 0)
for i in range(cluster.model.num_topics):
    topic_string = cluster.model.print_topic(i)
    for prob, word in [prob_word.split('*') for prob_word in topic_string.split(' + ')]:
        word_freq[word.replace('"', '')] += 1
        
sorted(word_freq.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('author', 41),
#  ('use', 28),
#  ('amp', 21),
#  ('new', 20),
#  ('ransomware', 14),
#  ('learn', 14),
#  ('make', 13),
#  ('malware', 13),
#  ('neural', 12),
#  ('security', 12),
#  ('datum', 12),
#  ('learning', 11),
#  ('code', 11),
#  ('get', 11),
#  ('look', 11),
#  ('people', 10),
#  ('year', 10),
#  ('time', 9),
#  ('ai', 9),
#  ('base', 9),
#  ('day', 8),
#  ('deep', 8),
#  ('write', 8),
#  ('next', 7),
#  ('know', 7),
#  ('networks', 7),
#  ('network', 7),
#  ('language', 7),
#  ('software', 7),
#  ('tool', 7),
#  ('open', 7),
#  ('attention', 6),
#  ('text', 6),
#  ('generation', 6),
#  ('machine', 6),
#  ('thank', 6),
#  ('really', 6),
#  ('target', 5),
#  ('approach', 5),
#  ('update', 5),
#  ('word', 5),
#  ('detail', 5),
#  ('service', 5),
#  ('show', 5),
#  ('paper', 5),
#  ('research', 5),
#  ('impact', 5),
#  ('file', 5),
#  ('another', 4),
#  ('mobile', 4),
#  ('deepmind', 4),
#  ('translation', 4),
#  ('first', 4),
#  ('wannacry', 4),
#  ('go', 4),
#  ('find', 4),
#  ('also', 4),
#  ('week', 4),
#  ('report', 4),
#  ('cyber', 4),
#  ('memory', 3),
#  ('world', 3),
#  ('copy', 3),
#  ('slocker', 3),
#  ('happen', 3),
#  ('small', 3),
#  ('dialogue', 3),
#  ('take', 3),
#  ('think', 3),
#  ('enable', 3),
#  ('feature', 3),
#  ('campaign', 3),
#  ('source', 3),
#  ('gan', 3),
#  ('way', 3),
#  ('try', 3),
#  ('task', 3),
#  ('notpetya', 3),
#  ('user', 3),
#  ('still', 3),
#  ('semantic', 3),
#  ('android', 3),
#  ('sentiment', 3),
#  ('back', 3),
#  ('embedding', 3),
#  ('function', 2),
#  ('game', 2),
#  ('brain', 2),
#  ('without', 2),
#  ('supervised', 2),
#  ('one', 2),
#  ('study', 2),
#  ('high', 2),
#  ('bitcoin', 2),
#  ('natural_language', 2),
#  ('search', 2),
#  ('see', 2),
#  ('symantec', 2),
#  ('survey', 2),
#  ('news', 2),
#  ('could', 2),
#  ('want', 2),
#  ('clinical', 2),
#  ('deep_learning', 2),
#  ('visual', 2),
#  ('download', 2),
#  ('machine_translation', 2),
#  ('multimodal', 2),
#  ('read', 2),
#  ('petya', 2),
#  ('woman', 2),
#  ('public', 2),
#  ('example', 2),
#  ('old', 2),
#  ('ne', 2),
#  ('cross', 2),
#  ('behavior', 2),
#  ('offer', 2),
#  ('would', 2),
#  ('natural', 2),
#  ('model', 2),
#  ('algorithms', 2),
#  ('mean', 2),
#  ('help', 2),
#  ('analysis', 2),
#  ('pytorch', 2),
#  ('system', 2),
#  ('image', 2),
#  ('july', 2),
#  ('join', 2),
#  ('let', 2),
#  ('call', 2),
#  ('much', 2),
#  ('variant', 2),
#  ('change', 2),
#  ('build', 2),
#  ('via', 2),
#  ('neural_network', 2),
#  ('speak', 2),
#  ('unit', 2),
#  ('post', 2),
#  ('process', 2),
#  ('someone', 2),
#  ('vs', 2),
#  ('end', 2),
#  ('project', 1),
#  ('induction', 1),
#  ('medical', 1),
#  ('feedback', 1),
#  ('name', 1),
#  ('open_source', 1),
#  ('challenges', 1),
#  ('deep_network', 1),
#  ('interactive', 1),
#  ('models', 1),
#  ('instead', 1),
#  ('mimicking', 1),
#  ('password', 1),
#  ('challenges_end', 1),
#  ('say', 1),
#  ('development', 1),
#  ('last', 1),
#  ('combine', 1),
#  ('lingual', 1),
#  ('training', 1),
#  ('various', 1),
#  ('adgholas', 1),
#  ('imagination', 1),
#  ('library', 1),
#  ('history', 1),
#  ('test', 1),
#  ('selection', 1),
#  ('shared_task', 1),
#  ('grammatical', 1),
#  ('schema', 1),
#  ('decrypt', 1),
#  ('processing_clinical', 1),
#  ('summarization', 1),
#  ('cost', 1),
#  ('researcher', 1),
#  ('locomotion', 1),
#  ('composition_behavior', 1),
#  ('tutor', 1),
#  ('dataset_new', 1),
#  ('bot', 1),
#  ('difference', 1),
#  ('aware', 1),
#  ('identification', 1),
#  ('conditional_variational', 1),
#  ('developer', 1),
#  ('image_description', 1),
#  ('spread', 1),
#  ('train', 1),
#  ('analyze', 1),
#  ('question', 1),
#  ('race', 1),
#  ('web', 1),
#  ('simple_approach', 1),
#  ('composition', 1),
#  ('technique', 1),
#  ('programming', 1),
#  ('keras', 1),
#  ('hybrid', 1),
#  ('dialog', 1),
#  ('application', 1),
#  ('learning_base', 1),
#  ('using', 1),
#  ('wgan', 1),
#  ('server', 1),
#  ('metric', 1),
#  ('kit', 1),
#  ('tensorflow', 1),
#  ('data', 1),
#  ('roulette', 1),
#  ('art', 1),
#  ('visually', 1),
#  ('index', 1),
#  ('word_embedding', 1),
#  ('dataset', 1),
#  ('machine_learning', 1),
#  ('line', 1),
#  ('rule', 1),
#  ('document_embedding', 1),
#  ('environments', 1),
#  ('single', 1),
#  ('context', 1),
#  ('experience', 1),
#  ('birthday', 1),
#  ('seven', 1),
#  ('watch', 1),
#  ('countermeasure', 1),
#  ('sentiment_analysis', 1),
#  ('manage', 1),
#  ('businessprocesscompromise', 1),
#  ('discuss', 1),
#  ('convolution', 1),
#  ('range', 1),
#  ('framework', 1),
#  ('macro', 1),
#  ('thrive', 1),
#  ('attribution', 1),
#  ('program', 1),
#  ('processing', 1),
#  ('api', 1),
#  ('give', 1),
#  ('chip', 1),
#  ('align', 1),
#  ('tech', 1),
#  ('hack', 1),
#  ('embedded_deep', 1),
#  ('ticket', 1),
#  ('visual_text', 1),
#  ('baidu', 1),
#  ('shakespeariz', 1),
#  ('content', 1),
#  ('explanations', 1),
#  ('sentence', 1),
#  ('come', 1),
#  ('morning', 1),
#  ('sequence', 1),
#  ('motion', 1),
#  ('cross_linguistic', 1),
#  ('create', 1),
#  ('description', 1),
#  ('drive', 1),
#  ('actor', 1),
#  ('aim', 1),
#  ('imitation', 1),
#  ('piece', 1),
#  ('late', 1),
#  ('features', 1),
#  ('interest', 1),
#  ('bulletin', 1),
#  ('segmentation', 1),
#  ('humphrys', 1),
#  ('mixed', 1),
#  ('cybersecurity', 1),
#  ('working', 1),
#  ('fi', 1),
#  ('simple', 1),
#  ('yes', 1),
#  ('conditional', 1),
#  ('implementation', 1),
#  ('pair', 1),
#  ('attach', 1),
#  ('word_prediction', 1),
#  ('fact', 1),
#  ('attacker', 1),
#  ('media', 1),
#  ('touch', 1),
#  ('similarity', 1),
#  ('automatic', 1),
#  ('single_queue', 1),
#  ('interviews', 1),
#  ('move', 1),
#  ('blog', 1),
#  ('answer', 1),
#  ('propose', 1),
#  ('pro', 1),
#  ('variational', 1),
#  ('gesture', 1),
#  ('malvertis', 1),
#  ('reinflection', 1),
#  ('recurrent', 1),
#  ('embeddings', 1),
#  ('keyword', 1),
#  ('attempt', 1),
#  ('without_translation', 1),
#  ('pm', 1),
#  ('pay', 1),
#  ('spotting', 1),
#  ('uzh', 1),
#  ('systems', 1),
#  ('decoding_neural', 1),
#  ('car', 1),
#  ('windows', 1),
#  ('wosign', 1),
#  ('ensor', 1),
#  ('wi', 1),
#  ('document', 1),
#  ('bebloh', 1),
#  ('sigmorphon', 1),
#  ('string', 1),
#  ('infosec', 1),
#  ('fourth', 1),
#  ('every', 1),
#  ('lesson', 1),
#  ('rhel', 1),
#  ('cryptocurrencie', 1),
#  ('brief', 1),
#  ('depth', 1),
#  ('slide', 1),
#  ('hire', 1),
#  ('dimension', 1),
#  ('polysemous', 1),
#  ('skill', 1),
#  ('footprint', 1),
#  ('interface', 1),
#  ('comment', 1),
#  ('internship', 1),
#  ('student', 1),
#  ('strategy', 1),
#  ('human', 1),
#  ('morphological', 1),
#  ('hear', 1),
#  ('automatic_generation', 1),
#  ('challenge', 1),
#  ('linguistic', 1),
#  ('spoken', 1),
#  ('product', 1),
#  ('video', 1),
#  ('starts', 1),
#  ('cross_lingual', 1),
#  ('everyone', 1),
#  ('parallel', 1),
#  ('recognition', 1),
#  ('shared', 1),
#  ('today', 1),
#  ('local', 1),
#  ('meet', 1),
#  ('yet', 1),
#  ('pxe', 1),
#  ('mechanism', 1),
#  ('emergence', 1),
#  ('affect', 1),
#  ('chris', 1),
#  ('john', 1),
#  ('framework_dialog', 1),
#  ('zip', 1),
#  ('rely', 1),
#  ('complexity', 1),
#  ('embedded', 1),
#  ('behaviours', 1),
#  ('sample', 1),
#  ('xls', 1),
#  ('urlzone', 1),
#  ('citation', 1),
#  ('outbreak', 1),
#  ('view', 1),
#  ('spoken_dialogue', 1),
#  ('tensor', 1),
#  ('peter', 1),
#  ('physics', 1),
#  ('event', 1),
#  ('generate', 1),
#  ('shadow', 1),
#  ('puzzle', 1),
#  ('global', 1),
#  ('queue', 1),
#  ('prediction', 1),
#  ('fluids', 1),
#  ('dual', 1),
#  ('gen', 1),
#  ('recent', 1),
#  ('teach', 1),
#  ('science', 1),
#  ('python', 1),
#  ('learns', 1),
#  ('convolutional', 1),
#  ('email', 1),
#  ('malspam', 1),
#  ('submission', 1),
#  ('victim', 1),
#  ('possible', 1),
#  ('solar', 1),
#  ('base_neural', 1),
#  ('automate', 1),
#  ('future', 1),
#  ('review', 1),
#  ('difference_similarity', 1),
#  ('factorization', 1),
#  ('programmer', 1),
#  ('enriched', 1),
#  ('end_generation', 1),
#  ('guide', 1),
#  ('btcware', 1),
#  ('competition', 1),
#  ('do', 1),
#  ('mt', 1),
#  ('morphological_reinflection', 1),
#  ('social', 1),
#  ('ever', 1),
#  ('computational', 1),
#  ('classification', 1),
#  ('gpu', 1),
#  ('acquisition', 1),
#  ('decoding', 1),
#  ('phishing', 1),
#  ('nomination', 1),
#  ('szor', 1),
#  ('determine', 1),
#  ('management', 1),
#  ('av', 1),
#  ('documentation', 1),
#  ('context_aware', 1),
#  ('claim', 1),
#  ('capture', 1),
#  ('learn_polysemous', 1),
#  ('gtx', 1),
#  ('interactive_tool', 1)]
