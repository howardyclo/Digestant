# %%
import sys
sys.path.append('/data/Digestant/datasource/')
sys.path.append('/data/secure/')
import cluster
import setup
# Out:
# export TWITTER_consumer_key=WiUVodW9Mmdlj8o2EzApCxEWe
# export TWITTER_consumer_secret=hUAAIaVCNs4hzR050TrGrKIq2E27twQ3xQdyOGDTqPwih7dYvA
# export TWITTER_access_token=883254398075322368-UYfglpwLaBbafuV0LXShJ9ZPtrjjEus
# export TWITTER_token_secret=HtoSSn1uL5WsftTWe2ZAMHSxnaJ3qd0w1TKY20KT7VCeO
# export REDDIT_client_id=hHMqHsK2oyERBA
# export REDDIT_client_secret=bjL5skFBIm3HMtuCh98P1jQwgMg
# export REDDIT_password=ilove@trend
# export REDDIT_user_agent=digentant
# export REDDIT_username=sparktsao

# %%
import os
print(os.environ['TWITTER_consumer_key'])
# Out:
# WiUVodW9Mmdlj8o2EzApCxEWe

# %%
object1 = cluster.datahelper()
df1 =object1.getdata("summarization")

# %%
df1
# Out:
#                 auther           created  \
# 0      StopMalvertisin  2017-07-17 03-00
# 1      StopMalvertisin  2017-07-17 00-00
# 2      StopMalvertisin  2017-07-16 17-00
# 3      StopMalvertisin  2017-07-16 15-00
# 4      StopMalvertisin  2017-07-16 12-30
# 5      StopMalvertisin  2017-07-15 21-30
# 6      StopMalvertisin  2017-07-15 11-00
# 7      StopMalvertisin  2017-07-15 10-30
# 8      StopMalvertisin  2017-07-14 22-00
# 9      StopMalvertisin  2017-07-14 20-30
# 10     StopMalvertisin  2017-07-14 19-00
# 11     StopMalvertisin  2017-07-14 18-30
# 12     StopMalvertisin  2017-07-14 18-30
# 13     StopMalvertisin  2017-07-14 18-30
# 14     StopMalvertisin  2017-07-14 18-30
# 15     StopMalvertisin  2017-07-14 18-00
# 16     StopMalvertisin  2017-07-14 17-30
# 17     StopMalvertisin  2017-07-14 17-30
# 18     StopMalvertisin  2017-07-14 17-30
# 19     StopMalvertisin  2017-07-14 17-30
# 20     StopMalvertisin  2017-07-14 17-30
# 21     StopMalvertisin  2017-07-14 17-30
# 22     StopMalvertisin  2017-07-14 17-00
# 23     StopMalvertisin  2017-07-14 17-00
# 24     StopMalvertisin  2017-07-14 17-00
# 25     StopMalvertisin  2017-07-14 17-00
# 26     StopMalvertisin  2017-07-14 16-30
# 27     StopMalvertisin  2017-07-14 16-30
# 28     StopMalvertisin  2017-07-14 16-30
# 29     StopMalvertisin  2017-07-14 16-30
# ..                 ...               ...
# 270            benanne        2014-12-02
# 271           lukovkin        2016-04-12
# 272          maruchanr        2017-04-14
# 273         slowmantic        2014-05-27
# 274          mimighost        2016-10-12
# 275         abhishkk65        2016-08-10
# 276             fhoffa        2017-07-11
# 277              vkhuc        2016-06-01
# 278               vrld        2014-11-20
# 279             evc123        2017-01-18
# 280           deep2018        2017-06-23
# 281         zionsrogue        2014-06-09
# 282             gwulfs        2016-03-22
# 283            harrism        2014-09-08
# 284               mttd        2016-03-21
# 285             bdamos        2015-10-13
# 286          shmageggy        2016-05-18
# 287           breandan        2017-07-09
# 288            lopespm        2016-10-06
# 289               jakn        2017-02-27
# 290            benanne        2014-08-05
# 291            harrism        2016-06-29
# 292       jeremyhoward        2017-03-21
# 293      JasonYosinski        2014-12-17
# 294            terryum        2016-06-03
# 295  SarcasticMetaName        2016-10-26
# 296              truri        2016-01-23
# 297            egrefen        2015-02-26
# 298           olaf_nij        2014-02-18
# 299        brotherrain        2016-01-29
#
#                                                    raw      tag  \
# 0    Status(contributors=None, _json={'contributors...  twitter
# 1    Status(contributors=None, _json={'contributors...  twitter
# 2    Status(contributors=None, _json={'contributors...  twitter
# 3    Status(contributors=None, _json={'contributors...  twitter
# 4    Status(contributors=None, _json={'contributors...  twitter
# 5    Status(contributors=None, _json={'contributors...  twitter
# 6    Status(contributors=None, _json={'contributors...  twitter
# 7    Status(contributors=None, _json={'contributors...  twitter
# 8    Status(contributors=None, _json={'contributors...  twitter
# 9    Status(contributors=None, _json={'contributors...  twitter
# 10   Status(contributors=None, _json={'contributors...  twitter
# 11   Status(contributors=None, _json={'contributors...  twitter
# 12   Status(contributors=None, _json={'contributors...  twitter
# 13   Status(contributors=None, _json={'contributors...  twitter
# 14   Status(contributors=None, _json={'contributors...  twitter
# 15   Status(contributors=None, _json={'contributors...  twitter
# 16   Status(contributors=None, _json={'contributors...  twitter
# 17   Status(contributors=None, _json={'contributors...  twitter
# 18   Status(contributors=None, _json={'contributors...  twitter
# 19   Status(contributors=None, _json={'contributors...  twitter
# 20   Status(contributors=None, _json={'contributors...  twitter
# 21   Status(contributors=None, _json={'contributors...  twitter
# 22   Status(contributors=None, _json={'contributors...  twitter
# 23   Status(contributors=None, _json={'contributors...  twitter
# 24   Status(contributors=None, _json={'contributors...  twitter
# 25   Status(contributors=None, _json={'contributors...  twitter
# 26   Status(contributors=None, _json={'contributors...  twitter
# 27   Status(contributors=None, _json={'contributors...  twitter
# 28   Status(contributors=None, _json={'contributors...  twitter
# 29   Status(contributors=None, _json={'contributors...  twitter
# ..                                                 ...      ...
# 270                                             2o10zs   reddit
# 271                                             4ec4fm   reddit
# 272                                             65aoos   reddit
# 273                                             26m16j   reddit
# 274                                             570pkw   reddit
# 275                                             4wybub   reddit
# 276                                             6mhphp   reddit
# 277                                             4ly9oq   reddit
# 278                                             2mvj0s   reddit
# 279                                             5olwep   reddit
# 280                                             6ixbj6   reddit
# 281                                             27paaq   reddit
# 282                                             4bhhhk   reddit
# 283                                             2frcgf   reddit
# 284                                             4badnc   reddit
# 285                                             3okumr   reddit
# 286                                             4jrqgq   reddit
# 287                                             6m5csz   reddit
# 288                                             565f3z   reddit
# 289                                             5wgecr   reddit
# 290                                             2cozew   reddit
# 291                                             4qd040   reddit
# 292                                             60k77j   reddit
# 293                                             2phkrd   reddit
# 294                                             4mc6qg   reddit
# 295                                             59hwh6   reddit
# 296                                             426q0t   reddit
# 297                                             2x4yy1   reddit
# 298                                             1y7qdp   reddit
# 299                                             437qop   reddit
#
#                                                  title  cid  \
# 0    The Register | Burglary in mind? Easy, just pw...    0
# 1    Didier Stevens | Beta: format-bytes.py https:/...    0
# 2    CSO Online | White House released voter-fraud ...    0
# 3    CSO Online | IDG Contributor Network: Cybersec...    0
# 4    Krebs | Porn Spam Botnet Has Evil Twitter Twin...    0
# 5    Didier Stevens | Mimikatz Videos https://t.co/...    0
# 6    The Hacker News | Two New Platforms Found Offe...    1
# 7    Darknet | dork-cli – Command-line Google Dork ...    0
# 8    eSecurityPlanet | Cisco Aims to Improve Cloud ...    1
# 9    InfoSec Institute | Security+ Job Outlook and ...    1
# 10   SecurityWeek | Risk Intelligence Firm Flashpoi...    1
# 11   Dark Reading | Cloud AV Can Serve as an Avenue...    1
# 12   The Hacker News | Awesome! WhatsApp Now Lets Y...    1
# 13   Network World | What is IoT? https://t.co/zZA5...    0
# 14   Naked Security | News in brief: Oz law ‘trumps...    0
# 15   Dark Reading | 50,000 Machines Remain Vulnerab...    1
# 16   Infosec Island | How to Prevent Ransomware and...    1
# 17   SecurityWeek | Dark Web Market AlphaBay Goes D...    1
# 18   SecurityWeek | Insider Steals Customer Data Fr...    0
# 19   InfoSec Institute | Security+: Earning Continu...    0
# 20   ZDNet | Trump voter commission releases voter ...    0
# 21   Naked Security | BUPA breach – why names and a...    1
# 22   Malwarebytes | Keeping up with the Petyas: Dem...    0
# 23   Threatpost | Siemens Patches Authentication By...    0
# 24   Threatpost | NemucodAES Ransomware, Kovter Cli...    0
# 25   Naked Security | Vault 7: new WikiLeaks dump d...    1
# 26   Dark Reading | AsTech Offers a $5 Million Secu...    1
# 27   SecurityWeek | Atlassian Launches Public Bug B...    1
# 28   ESET | Beware bogus ‘WhatsApp subscription end...    1
# 29   Naked Security | Whose job is it to keep us sa...    0
# ..                                                 ...  ...
# 270                            Deep learning for chess    1
# 271  Keras 1.0 - the major update of Deep Learning ...    1
# 272  [P] Deep Patient: An Unsupervised Representati...    1
# 273          The Flaw Lurking In Every Deep Neural Net    1
# 274  [Project] Analyzing 50k fonts using deep neura...    0
# 275  Intel pays $350 million to buy deep-learning s...    0
# 276  [P] Predicting the Success of a Reddit Submiss...    0
# 277      Deep Reinforcement Learning: Pong from Pixels    1
# 278  Deep Visual-Semantic Alignments for Generating...    1
# 279  [D] Engineering is the bottleneck in (Deep Lea...    1
# 280  [P]Demo App For Skin Cancer Diagnosis in Real ...    1
# 281  Trends in machine learning...and why I'm sick ...    0
# 282  Deep Advances in Generative Modeling - Alec Ra...    1
# 283  cuDNN: GPU-Accelerated Deep Neural Network Lib...    0
# 284  Do Deep Convolutional Nets Really Need to be D...    0
# 285  OpenFace: Face recognition with Google's FaceN...    1
# 286  Google attempting to patent deep neural networ...    0
# 287                     [D] Deep learning in the brain    0
# 288  Deep Reinforcement Learning: Playing a Racing ...    1
# 289  [R] [1701.07274] Deep Reinforcement Learning: ...    1
# 290   Recommending music on Spotify with deep learning    0
# 291  NVIDIA Docker: Deep Learning Framework Deploym...    1
# 292   [P] Linear algebra cheat sheet for deep learning    0
# 293  Video explaining paper: Deep Neural Networks a...    0
# 294   Awesome list - Deep learning papers (since 2010)    0
# 295  AI Pioneer Yoshua Bengio Is Launching Element....    1
# 296  Robot Control with Distributed Deep Reinforcem...    0
# 297  Google DeepMind Nature Paper: Human-level cont...    1
# 298  Deep Learning Pioneer, Yoshua Bengio will be d...    0
# 299                              Deep Learning Courses    1
#
#                    c_desc
# 0    The Register | Burgl
# 1    Didier Stevens | Bet
# 2    CSO Online | White H
# 3    CSO Online | IDG Con
# 4    Krebs | Porn Spam Bo
# 5    Didier Stevens | Mim
# 6    The Hacker News | Tw
# 7    Darknet | dork-cli –
# 8    eSecurityPlanet | Ci
# 9    InfoSec Institute |
# 10   SecurityWeek | Risk
# 11   Dark Reading | Cloud
# 12   The Hacker News | Aw
# 13   Network World | What
# 14   Naked Security | New
# 15   Dark Reading | 50,00
# 16   Infosec Island | How
# 17   SecurityWeek | Dark
# 18   SecurityWeek | Insid
# 19   InfoSec Institute |
# 20   ZDNet | Trump voter
# 21   Naked Security | BUP
# 22   Malwarebytes | Keepi
# 23   Threatpost | Siemens
# 24   Threatpost | Nemucod
# 25   Naked Security | Vau
# 26   Dark Reading | AsTec
# 27   SecurityWeek | Atlas
# 28   ESET | Beware bogus
# 29   Naked Security | Who
# ..                    ...
# 270  Deep learning for ch
# 271  Keras 1.0 - the majo
# 272  [P] Deep Patient: An
# 273  The Flaw Lurking In
# 274  [Project] Analyzing
# 275  Intel pays $350 mill
# 276  [P] Predicting the S
# 277  Deep Reinforcement L
# 278  Deep Visual-Semantic
# 279  [D] Engineering is t
# 280  [P]Demo App For Skin
# 281  Trends in machine le
# 282  Deep Advances in Gen
# 283  cuDNN: GPU-Accelerat
# 284  Do Deep Convolutiona
# 285  OpenFace: Face recog
# 286  Google attempting to
# 287  [D] Deep learning in
# 288  Deep Reinforcement L
# 289  [R] [1701.07274] Dee
# 290  Recommending music o
# 291  NVIDIA Docker: Deep
# 292  [P] Linear algebra c
# 293  Video explaining pap
# 294  Awesome list - Deep
# 295  AI Pioneer Yoshua Be
# 296  Robot Control with D
# 297  Google DeepMind Natu
# 298  Deep Learning Pionee
# 299  Deep Learning Course
#
# [300 rows x 7 columns]

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
g = sns.countplot(x='tag', data=df1)
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %%
pwd
# Out:
# '/home/howard_lo/digestant/notebooks'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import mpld3
from mpld3 import plugins
np.random.seed(9615)

# generate df
N = 100
df = pd.DataFrame((.1 * (np.random.random((N, 5)) - .5)).cumsum(0),
                  columns=['a', 'b', 'c', 'd', 'e'],)

# plot line + confidence interval
fig, ax = plt.subplots()
ax.grid(True, alpha=0.3)

for key, val in df.iteritems():
    l, = ax.plot(val.index, val.values, label=key)
    ax.fill_between(val.index,
                    val.values * .5, val.values * 1.5,
                    color=l.get_color(), alpha=.4)

# define interactive legend

handles, labels = ax.get_legend_handles_labels() # return lines and labels
interactive_legend = plugins.InteractiveLegendPlugin(zip(handles,
                                                         ax.collections),
                                                     labels,
                                                     alpha_unsel=0.5,
                                                     alpha_over=1.5, 
                                                     start_visible=True)
plugins.connect(fig, interactive_legend)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Interactive legend', size=20)

mpld3.display()
# Out:
# <style>
#
#     .legend-box {
#       cursor: pointer;
#     }
#
# </style>
#
# <div id="fig_el245941403189621559285980241547"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("interactive_legend", InteractiveLegend);
#     InteractiveLegend.prototype = Object.create(mpld3.Plugin.prototype);
#     InteractiveLegend.prototype.constructor = InteractiveLegend;
#     InteractiveLegend.prototype.requiredProps = ["element_ids", "labels"];
#     InteractiveLegend.prototype.defaultProps = {"ax":null,
#                                                 "alpha_unsel":0.2,
#                                                 "alpha_over":1.0,
#                                                 "start_visible":true}
#     function InteractiveLegend(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     InteractiveLegend.prototype.draw = function(){
#         var alpha_unsel = this.props.alpha_unsel;
#         var alpha_over = this.props.alpha_over;
#
#         var legendItems = new Array();
#         for(var i=0; i<this.props.labels.length; i++){
#             var obj = {};
#             obj.label = this.props.labels[i];
#
#             var element_id = this.props.element_ids[i];
#             mpld3_elements = [];
#             for(var j=0; j<element_id.length; j++){
#                 var mpld3_element = mpld3.get_element(element_id[j], this.fig);
#
#                 // mpld3_element might be null in case of Line2D instances
#                 // for we pass the id for both the line and the markers. Either
#                 // one might not exist on the D3 side
#                 if(mpld3_element){
#                     mpld3_elements.push(mpld3_element);
#                 }
#             }
#
#             obj.mpld3_elements = mpld3_elements;
#             obj.visible = this.props.start_visible[i]; // should become be setable from python side
#             legendItems.push(obj);
#             set_alphas(obj, false);
#         }
#
#         // determine the axes with which this legend is associated
#         var ax = this.props.ax
#         if(!ax){
#             ax = this.fig.axes[0];
#         } else{
#             ax = mpld3.get_element(ax, this.fig);
#         }
#
#         // add a legend group to the canvas of the figure
#         var legend = this.fig.canvas.append("svg:g")
#                                .attr("class", "legend");
#
#         // add the rectangles
#         legend.selectAll("rect")
#                 .data(legendItems)
#                 .enter().append("rect")
#                 .attr("height", 10)
#                 .attr("width", 25)
#                 .attr("x", ax.width + ax.position[0] + 25)
#                 .attr("y",function(d,i) {
#                            return ax.position[1] + i * 25 + 10;})
#                 .attr("stroke", get_color)
#                 .attr("class", "legend-box")
#                 .style("fill", function(d, i) {
#                            return d.visible ? get_color(d) : "white";})
#                 .on("click", click).on('mouseover', over).on('mouseout', out);
#
#         // add the labels
#         legend.selectAll("text")
#               .data(legendItems)
#               .enter().append("text")
#               .attr("x", function (d) {
#                            return ax.width + ax.position[0] + 25 + 40;})
#               .attr("y", function(d,i) {
#                            return ax.position[1] + i * 25 + 10 + 10 - 1;})
#               .text(function(d) { return d.label });
#
#
#         // specify the action on click
#         function click(d,i){
#             d.visible = !d.visible;
#             d3.select(this)
#               .style("fill",function(d, i) {
#                 return d.visible ? get_color(d) : "white";
#               })
#             set_alphas(d, false);
#
#         };
#
#         // specify the action on legend overlay
#         function over(d,i){
#              set_alphas(d, true);
#         };
#
#         // specify the action on legend overlay
#         function out(d,i){
#              set_alphas(d, false);
#         };
#
#         // helper function for setting alphas
#         function set_alphas(d, is_over){
#             for(var i=0; i<d.mpld3_elements.length; i++){
#                 var type = d.mpld3_elements[i].constructor.name;
#
#                 if(type =="mpld3_Line"){
#                     var current_alpha = d.mpld3_elements[i].props.alpha;
#                     var current_alpha_unsel = current_alpha * alpha_unsel;
#                     var current_alpha_over = current_alpha * alpha_over;
#                     d3.select(d.mpld3_elements[i].path[0][0])
#                         .style("stroke-opacity", is_over ? current_alpha_over :
#                                                 (d.visible ? current_alpha : current_alpha_unsel))
#                         .style("stroke-width", is_over ?
#                                 alpha_over * d.mpld3_elements[i].props.edgewidth : d.mpld3_elements[i].props.edgewidth);
#                 } else if((type=="mpld3_PathCollection")||
#                          (type=="mpld3_Markers")){
#                     var current_alpha = d.mpld3_elements[i].props.alphas[0];
#                     var current_alpha_unsel = current_alpha * alpha_unsel;
#                     var current_alpha_over = current_alpha * alpha_over;
#                     d3.selectAll(d.mpld3_elements[i].pathsobj[0])
#                         .style("stroke-opacity", is_over ? current_alpha_over :
#                                                 (d.visible ? current_alpha : current_alpha_unsel))
#                         .style("fill-opacity", is_over ? current_alpha_over :
#                                                 (d.visible ? current_alpha : current_alpha_unsel));
#                 } else{
#                     console.log(type + " not yet supported");
#                 }
#             }
#         };
#
#
#         // helper function for determining the color of the rectangles
#         function get_color(d){
#             var type = d.mpld3_elements[0].constructor.name;
#             var color = "black";
#             if(type =="mpld3_Line"){
#                 color = d.mpld3_elements[0].props.edgecolor;
#             } else if((type=="mpld3_PathCollection")||
#                       (type=="mpld3_Markers")){
#                 color = d.mpld3_elements[0].props.facecolors[0];
#             } else{
#                 console.log(type + " not yet supported");
#             }
#             return color;
#         };
#     };
#
#        mpld3.draw_figure("fig_el245941403189621559285980241547", {"plugins": [{"type": "reset"}, {"button": true, "enabled": false, "type": "zoom"}, {"button": true, "enabled": false, "type": "boxzoom"}, {"element_ids": [["el24594140318957863208", "el24594140318957863208pts", "el24594140318962062000"], ["el24594140318961266024", "el24594140318961266024pts", "el24594140318961265856"], ["el24594140318961294528", "el24594140318961294528pts", "el24594140318961294360"], ["el24594140318961314504", "el24594140318961314504pts", "el24594140318961314336"], ["el24594140318961330720", "el24594140318961330720pts", "el24594140318961330552"]], "ax": null, "start_visible": [true, true, true, true, true], "alpha_unsel": 0.5, "labels": ["a", "b", "c", "d", "e"], "alpha_over": 1.5, "type": "interactive_legend"}], "height": 288.0, "data": {"data01": [[0.0, -0.03642884113402683, 0.019299182069209976, 0.029587000331469705, 0.03807890632912528, 0.020197298763405327], [1.0, -0.06287307371216366, 0.004751101961091176, 0.03407727187939839, 0.06521088129999465, 0.06018617803748854], [2.0, -0.04728974242852726, 0.03973795852120203, 0.02287902572598466, 0.08333304005656617, 0.017062788016934664], [3.0, -6.239964622742344e-05, -0.0067448114544401, -0.001799478408416412, 0.09809993546125206, 0.
