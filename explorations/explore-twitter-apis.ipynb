# %%
import os
import json
import time
import pprint
import pickle
import tweepy

from collections import defaultdict

pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ## Authentication

# %%
# Consumer keys and access tokens, used for OAuth
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Creation of the actual interface, using authentication
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# ## Get User Information

# %%
pp.pprint(api.me()._json)
# Out:
# {   'contributors_enabled': False,
#     'created_at': 'Fri Jul 07 09:20:33 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 0,
#     'follow_request_sent': False,
#     'followers_count': 0,
#     'following': False,
#     'friends_count': 204,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 883254398075322368,
#     'id_str': '883254398075322368',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Digestant',
#     'needs_phone_verification': False,
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_location': None,
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Digestant9',
#     'statuses_count': 0,
#     'suspended': False,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}

# %% [markdown]
# ## Get Friends

# %%
friends = []
for friend in tweepy.Cursor(api.friends).items():
    friends.append(friend)

# %%
len(friends)
# Out:
# 205

# %%
# Search user index by screen_name
for i, friend in enumerate(friends):
    if friend._json['screen_name'] == 'TerryUm_ML':
        print(i)
        user_index = i
# Out:
# 198

# %%
# Print friend object
pp.pprint(vars(friends[user_index]))
# Out:
# {   '_api': <tweepy.api.API object at 0x10fae55f8>,
#     '_json': {   'blocked_by': False,
#                  'blocking': False,
#                  'contributors_enabled': False,
#                  'created_at': 'Fri Jan 20 04:46:32 +0000 2017',
#                  'default_profile': False,
#                  'default_profile_image': False,
#                  'description': 'A PhD student at UWaterloo. \n'
#                                 'Interested in DL for human motion.\n'
#                                 'Share DL papers on arXiv everyday.\n'
#                                 'Most-cited DL paper list (2012-2016) '
#                                 'https://t.co/H2yD8jey3N',
#                  'entities': {   'description': {   'urls': [   {   'display_url': 'goo.gl/VEl3g8',
#                                                                     'expanded_url': 'https://goo.gl/VEl3g8',
#                                                                     'indices': [   136,
#                                                                                    159],
#                                                                     'url': 'https://t.co/H2yD8jey3N'}]},
#                                  'url': {   'urls': [   {   'display_url': 'terryum.io',
#                                                             'expanded_url': 'http://terryum.io/',
#                                                             'indices': [0, 23],
#                                                             'url': 'https://t.co/6yNmHTGrxc'}]}},
#                  'favourites_count': 600,
#                  'follow_request_sent': False,
#                  'followers_count': 1176,
#                  'following': True,
#                  'friends_count': 170,
#                  'geo_enabled': False,
#                  'has_extended_profile': True,
#                  'id': 822304279037784065,
#                  'id_str': '822304279037784065',
#                  'is_translation_enabled': False,
#                  'is_translator': False,
#                  'lang': 'en',
#                  'listed_count': 28,
#                  'live_following': False,
#                  'location': 'Waterloo, Ontario',
#                  'muting': False,
#                  'name': 'Terry Taewoong Um',
#                  'notifications': False,
#                  'profile_background_color': '000000',
#                  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                  'profile_background_tile': False,
#                  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/822304279037784065/1489099886',
#                  'profile_image_url': 'http://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg',
#                  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg',
#                  'profile_link_color': 'FF691F',
#                  'profile_sidebar_border_color': '000000',
#                  'profile_sidebar_fill_color': '000000',
#                  'profile_text_color': '000000',
#                  'profile_use_background_image': False,
#                  'protected': False,
#                  'screen_name': 'TerryUm_ML',
#                  'status': {   'contributors': None,
#                                'coordinates': None,
#                                'created_at': 'Mon Jul 10 21:37:37 +0000 2017',
#                                'entities': {   'hashtags': [],
#                                                'symbols': [],
#                                                'urls': [   {   'display_url': 'twitter.com/i/web/status/8…',
#                                                                'expanded_url': 'https://twitter.com/i/web/status/884527052652720128',
#                                                                'indices': [   104,
#                                                                               127],
#                                                                'url': 'https://t.co/oX4XrECpj8'}],
#                                                'user_mentions': []},
#                                'favorite_count': 18,
#                                'favorited': False,
#                                'geo': None,
#                                'id': 884527052652720128,
#                                'id_str': '884527052652720128',
#                                'in_reply_to_screen_name': None,
#                                'in_reply_to_status_id': None,
#                                'in_reply_to_status_id_str': None,
#                                'in_reply_to_user_id': None,
#                                'in_reply_to_user_id_str': None,
#                                'is_quote_status': False,
#                                'lang': 'en',
#                                'place': None,
#                                'possibly_sensitive': False,
#                                'retweet_count': 7,
#                                'retweeted': False,
#                                'source': '<a href="http://twitter.com" '
#                                          'rel="nofollow">Twitter Web '
#                                          'Client</a>',
#                                'text': '"An overview of gradient descent '
#                                        'optimization algorithms": SGD, '
#                                        'Adagrad, Adadelta, RMSprop, Adam, '
#                                        'etc.… https://t.co/oX4XrECpj8',
#                                'truncated': True},
#                  'statuses_count': 665,
#                  'time_zone': 'Eastern Time (US & Canada)',
#                  'translator_type': 'none',
#                  'url': 'https://t.co/6yNmHTGrxc',
#                  'utc_offset': -14400,
#                  'verified': False},
#     'blocked_by': False,
#     'blocking': False,
#     'contributors_enabled': False,
#     'created_at': datetime.datetime(2017, 1, 20, 4, 46, 32),
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'A PhD student at UWaterloo. \n'
#                    'Interested in DL for human motion.\n'
#                    'Share DL papers on arXiv everyday.\n'
#                    'Most-cited DL paper list (2012-2016) '
#                    'https://t.co/H2yD8jey3N',
#     'entities': {   'description': {   'urls': [   {   'display_url': 'goo.gl/VEl3g8',
#                                                        'expanded_url': 'https://goo.gl/VEl3g8',
#                                                        'indices': [136, 159],
#                                                        'url': 'https://t.co/H2yD8jey3N'}]},
#                     'url': {   'urls': [   {   'display_url': 'terryum.io',
#                                                'expanded_url': 'http://terryum.io/',
#                                                'indices': [0, 23],
#                                                'url': 'https://t.co/6yNmHTGrxc'}]}},
#     'favourites_count': 600,
#     'follow_request_sent': False,
#     'followers_count': 1176,
#     'following': True,
#     'friends_count': 170,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 822304279037784065,
#     'id_str': '822304279037784065',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 28,
#     'live_following': False,
#     'location': 'Waterloo, Ontario',
#     'muting': False,
#     'name': 'Terry Taewoong Um',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/822304279037784065/1489099886',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'TerryUm_ML',
#     'status': Status(_api=<tweepy.api.API object at 0x10fae55f8>, _json={'created_at': 'Mon Jul 10 21:37:37 +0000 2017', 'id': 884527052652720128, 'id_str': '884527052652720128', 'text': '"An overview of gradient descent optimization algorithms": SGD, Adagrad, Adadelta, RMSprop, Adam, etc.… https://t.co/oX4XrECpj8', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/oX4XrECpj8', 'expanded_url': 'https://twitter.com/i/web/status/884527052652720128', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [104, 127]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 7, 'favorite_count': 18, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2017, 7, 10, 21, 37, 37), id=884527052652720128, id_str='884527052652720128', text='"An overview of gradient descent optimization algorithms": SGD, Adagrad, Adadelta, RMSprop, Adam, etc.… https://t.co/oX4XrECpj8', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/oX4XrECpj8', 'expanded_url': 'https://twitter.com/i/web/status/884527052652720128', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [104, 127]}]}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=7, favorite_count=18, favorited=False, retweeted=False, possibly_sensitive=False, lang='en'),
#     'statuses_count': 665,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/6yNmHTGrxc',
#     'utc_offset': -14400,
#     'verified': False}

# %%
""" Get some useful information """
print(friends[user_index].name)
print(friends[user_index].screen_name)
print(friends[user_index].description)
print(friends[user_index].lang)
pp.pprint(friends[user_index].status._json) # We can use this to check whether a user has new tweet.
# Out:
# Terry Taewoong Um
# TerryUm_ML
# A PhD student at UWaterloo.
# Interested in DL for human motion.
# Share DL papers on arXiv everyday.
# Most-cited DL paper list (2012-2016) https://t.co/H2yD8jey3N
# en
# {   'contributors': None,
#     'coordinates': None,
#     'created_at': 'Mon Jul 10 21:37:37 +0000 2017',
#     'entities': {   'hashtags': [],
#                     'symbols': [],
#                     'urls': [   {   'display_url': 'twitter.com/i/web/status/8…',
#                                     'expanded_url': 'https://twitter.com/i/web/status/884527052652720128',
#                                     'indices': [104, 127],
#                                     'url': 'https://t.co/oX4XrECpj8'}],
#                     'user_mentions': []},
#     'favorite_count': 18,
#     'favorited': False,
#     'geo': None,
#     'id': 884527052652720128,
#     'id_str': '884527052652720128',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 7,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#               'Client</a>',
#     'text': '"An overview of gradient descent optimization algorithms": SGD, '
#             'Adagrad, Adadelta, RMSprop, Adam, etc.… https://t.co/oX4XrECpj8',
#     'truncated': True}

# %%
""" Get screen names from all friends
    Language code: https://dev.twitter.com/web/overview/languages
"""
# lang_blacklist = ['ja', 'ru', 'ko']
lang_blacklist = []
[(friend.name, friend.screen_name, friend.lang) for friend in friends if friend.lang not in lang_blacklist]
# Out:
# [('Han Xiao', 'hxiao', 'en'),
#  ('酪梨壽司', 'cwyuni', 'en'),
#  ('Apache Spark', 'ApacheSpark', 'en'),
#  ('holden karau', 'holdenkarau', 'en'),
#  ('Matei Zaharia', 'matei_zaharia', 'en'),
#  ('Tavis Ormandy', 'taviso', 'en'),
#  ('MalwareTech', 'MalwareTechBlog', 'en'),
#  ('Metasploit Project', 'metasploit', 'en'),
#  ('Payload Security', 'PayloadSecurity', 'de'),
#  ('Peter Haas', 'peter_haas', 'en'),
#  ('TrainMan', 'Tra1Nman', 'zh-tw'),
#  ('Joseph-CHC', 'jspchc', 'zh-tw'),
#  ('Hunter ExploitKit', 'hunter_exploit', 'en'),
#  ('Colin Hardy', 'cybercdh', 'en-gb'),
#  ('Deep Hub', 'Deep_Hub', 'en'),
#  ('wLcY', 'x9090', 'en'),
#  ('Haifei Li', 'HaifeiLi', 'en'),
#  ('Shadowserver', 'Shadowserver', 'en'),
#  ('MalwareTechLab', 'MalwareTechLab', 'en-gb'),
#  ('Fernando Mercês', 'MercesFernando', 'en'),
#  ('Маркус Кот', '0xD09AD0BED182', 'ru'),
#  ('Fabian Wosar', 'fwosar', 'en'),
#  ('Fyodor Y', 'fygrave', 'en'),
#  ('nao_sec', 'nao_sec', 'ja'),
#  ('Microsoft MMPC', 'msftmmpc', 'en'),
#  ('herrcore', 'herrcore', 'en'),
#  ('Robert McArdle', 'bobmcardle', 'en'),
#  ('Racco42', 'Racco42', 'en'),
#  ('Кириакос Экономоу', 'kyREcon', 'en'),
#  ('NCSC UK', 'ncsc', 'en-gb'),
#  ('Marc Rivero López', 'Seifreed', 'es'),
#  ('Benkow moʞuƎq', 'benkow_', 'fr'),
#  ('LockyBOT', 'LockyBOT', 'en'),
#  ('OD', '___OD___', 'en-gb'),
#  ('sysopfb', 'sysopfb', 'en'),
#  ('Patrick Perry', 'pjbperry', 'en'),
#  ('xozyain', 'xozyain', 'en'),
#  ('Luis Rocha', 'countuponsec', 'en'),
#  ('Jose Miguel Esparza', 'EternalTodo', 'es'),
#  ('x64dbg', 'x64dbg', 'en'),
#  ('SlavikInfoSec', 'SlavikInfoSec', 'en'),
#  ('FortiGuard Labs', 'FortiGuardLabs', 'en'),
#  ('Antelox', 'Antelox', 'it'),
#  ('Malwared', 'Malwared_', 'en'),
#  ('Manuel Caballero', 'magicmac2000', 'en'),
#  ('LiveOverflow', 'LiveOverflow', 'en'),
#  ('Cyber Maui', 'BelchSpeak', 'en'),
#  ('Symantec', 'symantec', 'en'),
#  ('Malwageddon', 'Malwageddon', 'en'),
#  ('ET Labs', 'ET_Labs', 'en'),
#  ('David Montenegro', 'CryptoInsane', 'es'),
#  ('Matthew Mesa', 'mesa_matt', 'en'),
#  ('ききょう', 'kk_ch1', 'ja'),
#  ('JAMESWT', 'JAMESWT_MHT', 'it'),
#  ('Cuckoo Sandbox', 'cuckoosandbox', 'en'),
#  ('Jerome Dangu', 'j_rom_', 'en'),
#  ('ExecuteMalware', 'executemalware', 'en'),
#  ('MalwareHunterTeam', 'malwrhunterteam', 'en'),
#  ('Justin Ragghianti', 'RagsOTX', 'en'),
#  ('StratosphereIPS', 'StratosphereIPS', 'en'),
#  ('Virus Bulletin', 'virusbtn', 'en'),
#  ('hasherezade', 'hasherezade', 'en'),
#  ('edx', 'criznash', 'en'),
#  ('Broad Analysis', 'BroadAnalysis', 'en'),
#  ('Bʀʏᴀɴ', 'bry_campbell', 'en'),
#  ('William Metcalf', 'node5', 'en'),
#  ('Alęxandęr Hanęl', 'nullandnull', 'en'),
#  ('Natata', 'iNatata', 'en'),
#  ('Piotr Kijewski', 'piotrkijewski', 'en'),
#  ('TMMalAnalyst', 'tmmalanalyst', 'ja'),
#  ('News from the Lab', 'FSLabs', 'en'),
#  ('Conrad Longmore 🇪🇺', 'ConradLongmore', 'en'),
#  ('torch', 'TorchML', 'en'),
#  ('radare', 'radareorg', 'en'),
#  ('Karsten Hahn', 'struppigel', 'de'),
#  ('REhints', 'REhints', 'en'),
#  ('Dridex BOT', 'DridexBOT', 'en'),
#  ('codelancer', 'codelancer', 'en'),
#  ('R136a1', 'TheEnergyStory', 'de'),
#  ('TrendLabs', 'TrendLabs', 'en'),
#  ('Bart', 'bartblaze', 'en'),
#  ('briankrebs', 'briankrebs', 'en'),
#  ('peterkruse', 'peterkruse', 'en'),
#  ('Santiago Pontiroli', 'spontiroli', 'en'),
#  ('Chris Wakelin', 'EKwatcher', 'en'),
#  ('Jake Williams', 'MalwareJake', 'en'),
#  ('Anton Ivanov', 'antonivanovm', 'ru'),
#  ('malc0de', 'malc0de', 'en'),
#  ('The Practical Dev', 'ThePracticalDev', 'en'),
#  ('Clément Lecigne', '_clem1', 'en'),
#  ('powertool', 'ithurricanept', 'zh-cn'),
#  ('Martin Roesler', 'MartinRoesler', 'en'),
#  ('Jérôme Segura', 'jeromesegura', 'en'),
#  ('DevOps Reactions', 'devopsreactions', 'en'),
#  ('Darien Huss', 'darienhuss', 'en'),
#  ('Natalie Silvanovich', 'natashenka', 'en'),
#  ('Jake Warren', 'jakewarrentx', 'en'),
#  ('Aels Martin', 'aelsmartin', 'en'),
#  ('Techhelplist', 'Techhelplistcom', 'en'),
#  ('hugbomb', 'hugbomb', 'en'),
#  ('pixiv', 'pixiv', 'ja'),
#  ('Brad', 'malware_traffic', 'en'),
#  ('Kyle Wilhoit', 'lowcalspam', 'en'),
#  ('濵田譲治', 'JojiHamada', 'ja'),
#  ('webDEViL', 'w3bd3vil', 'en'),
#  ('Ivan Fratric', 'ifsecure', 'en'),
#  ('Roberto Martinez', 'robemtnez', 'en'),
#  ('Octave Klaba / Oles', 'olesovhcom', 'fr'),
#  ('Threatglass', 'threatglass', 'en'),
#  ('Peter Pi', 'heisecode', 'zh-cn'),
#  ('Jack', 'malwareforme', 'en'),
#  ('Snort 🐷', 'Snort', 'en'),
#  ('brooks_li', 'brooks_li', 'zh-CN'),
#  ('Timo Hirvonen', 'TimoHirvonen', 'en'),
#  ('Alexandru Maximciuc', 'amaximciuc', 'en'),
#  ('ExploitKitsMustDie', 'EkMustDie', 'en'),
#  ("Malekal's site", 'malekal_morte', 'fr'),
#  ('Anonymous', 'AnonymousGlobo', 'pt'),
#  ('Yonathan Klijnsma', 'ydklijnsma', 'en'),
#  ('Reid Wiseman', 'astro_reid', 'en'),
#  ('MileHighSocalClub', '__MHSC', 'en'),
#  ('refeia', 'refeia', 'en'),
#  ('Mike Bostock', 'mbostock', 'en'),
#  ('Frank Denis', 'jedisct1', 'en'),
#  ('カワタヒサシ', 'kawata_hisashi', 'ja'),
#  ('Travis Oliphant', 'teoliphant', 'en'),
#  ('Fernando Perez', 'fperez_org', 'en'),
#  ('Wes McKinney', 'wesmckinn', 'en'),
#  ('FBI', 'FBI', 'en'),
#  ('Neutral8✗9eR', '0x009AD6_810', 'ja'),
#  ('Jessica McKellar', 'jessicamckellar', 'en'),
#  ('wu shi', 'team509', 'en'),
#  ('KEENLAB', 'keen_lab', 'zh-cn'),
#  ('Yuki Chen', 'guhe120', 'en'),
#  ('PhysicalDrive0', 'PhysicalDrive0', 'en'),
#  ("Angelo Dell'Aera", 'angelodellaera', 'en'),
#  ('João Gouveia', 'jgouv', 'en'),
#  ('Dhia Mahjoub', 'DhiaLite', 'en'),
#  ('FireF0X', 'hFireF0X', 'en-gb'),
#  ('Artem I. Baranov', 'artem_i_baranov', 'ru'),
#  ('Artem I. Baranov', 'artem_i_baranov', 'ru'),
#  ('TwitPic', 'TwitPic', 'en'),
#  ('Xylitol', 'Xylit0l', 'en'),
#  ('Kafeine', 'kafeine', 'en'),
#  ('Andrej Karpathy', 'karpathy', 'en'),
#  ('Ian Goodfellow', 'goodfellow_ian', 'en'),
#  ('Hugo Larochelle', 'hugo_larochelle', 'en'),
#  ('Oriol Vinyals', 'OriolVinyalsML', 'en'),
#  ('Soumith Chintala', 'soumithchintala', 'en'),
#  ('Fei-Fei Li', 'drfeifei', 'en'),
#  ('Russ Salakhutdinov', 'rsalakhu', 'en'),
#  ('Richard', 'RichardSocher', 'en'),
#  ('Christopher Manning', 'chrmanning', 'en'),
#  ('Stanford NLP Group', 'stanfordnlp', 'en'),
#  ('Nando de Freitas', 'NandoDF', 'en'),
#  ('ML @ REDDIT', 'mxlearn', 'en'),
#  ('Kaggle', 'kaggle', 'en'),
#  ('Denny Britz', 'dennybritz', 'en'),
#  ('Kyunghyun Cho', 'kchonyc', 'en'),
#  ('Thang Luong', 'lmthang', 'en'),
#  ('DeepMind', 'DeepMindAI', 'en'),
#  ('distillpub', 'distillpub', 'en'),
#  ('Google Research', 'googleresearch', 'en'),
#  ('TensorFlow Community', 'TensorFlo', 'en'),
#  ('Sundar Pichai', 'sundarpichai', 'en'),
#  ('Mustafa Suleyman', 'mustafasuleymn', 'en'),
#  ('Google', 'Google', 'en'),
#  ('Demis Hassabis', 'demishassabis', 'en'),
#  ('Bill Gates', 'BillGates', 'en'),
#  ('Yann LeCun', 'ylecun', 'en'),
#  ('Elon Musk', 'elonmusk', 'en'),
#  ('Deep Learning Hub', 'DeepLearningHub', 'en'),
#  ('hardmaru', 'hardmaru', 'en'),
#  ('Andrew Ng', 'AndrewYNg', 'en'),
#  ('François Chollet', 'fchollet', 'en'),
#  ('OpenAI', 'OpenAI', 'en'),
#  ('Gabriel Synnaeve 📎', 'syhw', 'en'),
#  ('Microsoft Research', 'MSFTResearch', 'en'),
#  ('Sebastian Thrun', 'SebastianThrun', 'en'),
#  ('NIPS', 'NipsConference', 'en'),
#  ('Radim Řehůřek', 'RadimRehurek', 'en'),
#  ('Yarin', 'yaringal', 'en'),
#  ('lisha li', 'lishali88', 'en'),
#  ('Caiming Xiong', 'CaimingXiong', 'en'),
#  ('Matthew Honnibal', 'honnibal', 'en'),
#  ('TensorFlow', 'tensorflow', 'en'),
#  ('Google Brain', 'GoogleBrain', 'en'),
#  ("(((λ()(λ() 'yoav))))", 'yoavgo', 'en'),
#  ('CSAIL at MIT', 'MIT_CSAIL', 'en'),
#  ('Shao-Hua Sun', 'shaohua0116', 'en'),
#  ('Chris Olah', 'ch402', 'en'),
#  ('Greg Brockman', 'gdb', 'en'),
#  ('Baidu Research', 'BaiduResearch', 'en'),
#  ('arXiv CS-CL', 'arxiv_cscl', 'en'),
#  ('harvardnlp', 'harvardnlp', 'en'),
#  ('Alexander R Johansen', 'AlexRoseJo', 'en'),
#  ('YenChenLin', 'yen_chen_lin', 'en'),
#  ('michael_nielsen', 'michael_nielsen', 'en'),
#  ('Terry Taewoong Um', 'TerryUm_ML', 'en'),
#  ('shanjtwit', 'shanjabberwocky', 'zh-tw'),
#  ('Gensim', 'gensim_py', 'en'),
#  ('RaRe Technologies', 'RaReTechTeam', 'en'),
#  ('/MachineLearning', 'slashML', 'en'),
#  ('spark', 'spark68845621', 'en'),
#  ('HubertLin', 'HubertLin8787', 'en')]

# %% [markdown]
# ## Get A Friend's Tweets
# - `entities`: https://dev.twitter.com/overview/api/entities-in-twitter-objects

# %%
# Make initial request for most recent tweets (200 is the maximum allowed count)
screen_name = 'TerryUm_ML'
unfiltered_tweets = api.user_timeline(screen_name=screen_name, count=200)

# %%
len(unfiltered_tweets)
# Out:
# 200

# %%
# Filter tweets
def filter_tweets(tweets):
    lang_whitelist = ['en']
    no_reply = True

    if no_reply:
        tweets = [tweet for tweet in tweets if tweet.in_reply_to_screen_name is None]

    if lang_whitelist:
        tweets = [tweet for tweet in tweets if tweet.lang in lang_whitelist]

    return tweets

filtered_tweets = filter_tweets(unfiltered_tweets)
len(filtered_tweets)
# Out:
# 158

# %%
# Print tweet object
pp.pprint(filtered_tweets[0]._json)
# Out:
# {   'contributors': None,
#     'coordinates': None,
#     'created_at': 'Mon Jul 10 21:37:37 +0000 2017',
#     'entities': {   'hashtags': [],
#                     'symbols': [],
#                     'urls': [   {   'display_url': 'twitter.com/i/web/status/8…',
#                                     'expanded_url': 'https://twitter.com/i/web/status/884527052652720128',
#                                     'indices': [104, 127],
#                                     'url': 'https://t.co/oX4XrECpj8'}],
#                     'user_mentions': []},
#     'favorite_count': 18,
#     'favorited': False,
#     'geo': None,
#     'id': 884527052652720128,
#     'id_str': '884527052652720128',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 7,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web '
#               'Client</a>',
#     'text': '"An overview of gradient descent optimization algorithms": SGD, '
#             'Adagrad, Adadelta, RMSprop, Adam, etc.… https://t.co/oX4XrECpj8',
#     'truncated': True,
#     'user': {   'contributors_enabled': False,
#                 'created_at': 'Fri Jan 20 04:46:32 +0000 2017',
#                 'default_profile': False,
#                 'default_profile_image': False,
#                 'description': 'A PhD student at UWaterloo. \n'
#                                'Interested in DL for human motion.\n'
#                                'Share DL papers on arXiv everyday.\n'
#                                'Most-cited DL paper list (2012-2016) '
#                                'https://t.co/H2yD8jey3N',
#                 'entities': {   'description': {   'urls': [   {   'display_url': 'goo.gl/VEl3g8',
#                                                                    'expanded_url': 'https://goo.gl/VEl3g8',
#                                                                    'indices': [   136,
#                                                                                   159],
#                                                                    'url': 'https://t.co/H2yD8jey3N'}]},
#                                 'url': {   'urls': [   {   'display_url': 'terryum.io',
#                                                            'expanded_url': 'http://terryum.io/',
#                                                            'indices': [0, 23],
#                                                            'url': 'https://t.co/6yNmHTGrxc'}]}},
#                 'favourites_count': 600,
#                 'follow_request_sent': False,
#                 'followers_count': 1176,
#                 'following': True,
#                 'friends_count': 170,
#                 'geo_enabled': False,
#                 'has_extended_profile': True,
#                 'id': 822304279037784065,
#                 'id_str': '822304279037784065',
#                 'is_translation_enabled': False,
#                 'is_translator': False,
#                 'lang': 'en',
#                 'listed_count': 28,
#                 'location': 'Waterloo, Ontario',
#                 'name': 'Terry Taewoong Um',
#                 'notifications': False,
#                 'profile_background_color': '000000',
#                 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                 'profile_background_tile': False,
#                 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/822304279037784065/1489099886',
#                 'profile_image_url': 'http://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg',
#                 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg',
#                 'profile_link_color': 'FF691F',
#                 'profile_sidebar_border_color': '000000',
#                 'profile_sidebar_fill_color': '000000',
#                 'profile_text_color': '000000',
#                 'profile_use_background_image': False,
#                 'protected': False,
#                 'screen_name': 'TerryUm_ML',
#                 'statuses_count': 665,
#                 'time_zone': 'Eastern Time (US & Canada)',
#                 'translator_type': 'none',
#                 'url': 'https://t.co/6yNmHTGrxc',
#                 'utc_offset': -14400,
#                 'verified': False}}

# %% [markdown]
# ## Useful data of a tweet

# %%
# Get useful infomation from tweet object
def print_tweet(tweet):
    print('* created_at: {}'.format(tweet.created_at))
    print('* id: {}'.format(tweet.id))
    print('* lang: {}'.format(tweet.lang))
    print('* user name: {}'.format(tweet.user.name))
    print('* user screen name: {}'.format(tweet.user.screen_name))
    print('* user profile url: {}'.format(tweet.user.profile_image_url_https))
    print('* favorite_count: {}'.format(tweet.favorite_count))
    print('* retweet count: {}'.format(tweet.retweet_count))
    print('* text: {}'.format(tweet.text))
    print('* hashtags: {}'.format(tweet.entities.get('hashtags', [])))
    print('* symbols: {}'.format(tweet.entities.get('symbols', [])))
    print('* urls: {}'.format(tweet.entities.get('urls', [])))
    print('* user_mentions: {}'.format(tweet.entities.get('user_mentions', [])))
    print('-'*116)

# %%
for tweet in filtered_tweets:
    print_tweet(tweet)

# %% [markdown]
# ## Save Tweets as Pickle File
#
# ### Create folder for every friends

# %%
# Make dataset folder
dataset_folder_path = 'dataset/twitter/'
if not os.path.exists(dataset_folder_path):
    os.makedirs(dataset_folder_path)

# %%
# Create folder for each friend
for friend in friends:
    # Make folder
    friend_folder_path = os.path.join(dataset_folder_path, friend.screen_name) 
    if not os.path.exists(friend_folder_path):
        os.makedirs(friend_folder_path)

# %% [markdown]
# ### Crawl most recent 200 tweets from every friends and save to their corresponding folders

# %%
len(friends)
# Out:
# 205

# %%
# %%time

""" Each friend need 3 seconds to retrieve 200 most recent tweets. 
    We have 205 friends currently, so it needs about 10 minutes to process.
"""
def get_friends_tweets():
    
    friends_tweets = {friend.screen_name: {} for friend in friends}
    
    # For every friend, get their recent 200 tweets
    for i, friend in enumerate(friends):
        
        print('* Progess: ({}/{})'.format(i, len(friends)))
        print('* Retrieving {} ({})\'s tweets...'.format(friend.name, friend.screen_name))

        ###################################### 
        ## Get tweets by screen name
        ###################################### 
        tweets = api.user_timeline(screen_name=friend.screen_name, count=200)

        ###################################### 
        ## Segment tweets by date 
        ######################################
        print('* Segmenting {} ({})\'s tweets by date...'.format(friend.name, friend.screen_name))

        tweets_keyed_by_date = defaultdict(lambda: [])

        for tweet in tweets:
            date = tweet.created_at.strftime('%Y-%m-%d')
            tweets_keyed_by_date[date].append(tweet)
            
        # Store date-segemented tweets to the corresponding friend
        friends_tweets[friend.screen_name] = tweets_keyed_by_date
        
        print('-'*116)
        
    return friends_tweets

friends_tweets = get_friends_tweets()
# Out:
# * Process: (0/205)
# * User timeline api rate limit: (895/900)
# * Retrieving Han Xiao (hxiao)'s tweets...
# * Segmenting Han Xiao (hxiao)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (1/205)
# * User timeline api rate limit: (894/900)
# * Retrieving 酪梨壽司 (cwyuni)'s tweets...
# * Segmenting 酪梨壽司 (cwyuni)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (2/205)
# * User timeline api rate limit: (893/900)
# * Retrieving Apache Spark (ApacheSpark)'s tweets...
# * Segmenting Apache Spark (ApacheSpark)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (3/205)
# * User timeline api rate limit: (892/900)
# * Retrieving holden karau (holdenkarau)'s tweets...
# * Segmenting holden karau (holdenkarau)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (4/205)
# * User timeline api rate limit: (891/900)
# * Retrieving Matei Zaharia (matei_zaharia)'s tweets...
# * Segmenting Matei Zaharia (matei_zaharia)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (5/205)
# * User timeline api rate limit: (890/900)
# * Retrieving Tavis Ormandy (taviso)'s tweets...
# * Segmenting Tavis Ormandy (taviso)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (6/205)
# * User timeline api rate limit: (889/900)
# * Retrieving MalwareTech (MalwareTechBlog)'s tweets...
# * Segmenting MalwareTech (MalwareTechBlog)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (7/205)
# * User timeline api rate limit: (888/900)
# * Retrieving Metasploit Project (metasploit)'s tweets...
# * Segmenting Metasploit Project (metasploit)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (8/205)
# * User timeline api rate limit: (887/900)
# * Retrieving Payload Security (PayloadSecurity)'s tweets...
# * Segmenting Payload Security (PayloadSecurity)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (9/205)
# * User timeline api rate limit: (886/900)
# * Retrieving Peter Haas (peter_haas)'s tweets...
# * Segmenting Peter Haas (peter_haas)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (10/205)
# * User timeline api rate limit: (885/900)
# * Retrieving TrainMan (Tra1Nman)'s tweets...
# * Segmenting TrainMan (Tra1Nman)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (11/205)
# * User timeline api rate limit: (884/900)
# * Retrieving Joseph-CHC (jspchc)'s tweets...
# * Segmenting Joseph-CHC (jspchc)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (12/205)
# * User timeline api rate limit: (883/900)
# * Retrieving Hunter ExploitKit (hunter_exploit)'s tweets...
# * Segmenting Hunter ExploitKit (hunter_exploit)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (13/205)
# * User timeline api rate limit: (882/900)
# * Retrieving Colin Hardy (cybercdh)'s tweets...
# * Segmenting Colin Hardy (cybercdh)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (14/205)
# * User timeline api rate limit: (881/900)
# * Retrieving Deep Hub (Deep_Hub)'s tweets...
# * Segmenting Deep Hub (Deep_Hub)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (15/205)
# * User timeline api rate limit: (880/900)
# * Retrieving wLcY (x9090)'s tweets...
# * Segmenting wLcY (x9090)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (16/205)
# * User timeline api rate limit: (879/900)
# * Retrieving Haifei Li (HaifeiLi)'s tweets...
# * Segmenting Haifei Li (HaifeiLi)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (17/205)
# * User timeline api rate limit: (878/900)
# * Retrieving Shadowserver (Shadowserver)'s tweets...
# * Segmenting Shadowserver (Shadowserver)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (18/205)
# * User timeline api rate limit: (877/900)
# * Retrieving MalwareTechLab (MalwareTechLab)'s tweets...
# * Segmenting MalwareTechLab (MalwareTechLab)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (19/205)
# * User timeline api rate limit: (876/900)
# * Retrieving Fernando Mercês (MercesFernando)'s tweets...
# * Segmenting Fernando Mercês (MercesFernando)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (20/205)
# * User timeline api rate limit: (875/900)
# * Retrieving Маркус Кот (0xD09AD0BED182)'s tweets...
# * Segmenting Маркус Кот (0xD09AD0BED182)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (21/205)
# * User timeline api rate limit: (874/900)
# * Retrieving Fabian Wosar (fwosar)'s tweets...
# * Segmenting Fabian Wosar (fwosar)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (22/205)
# * User timeline api rate limit: (873/900)
# * Retrieving Fyodor Y (fygrave)'s tweets...
# * Segmenting Fyodor Y (fygrave)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (23/205)
# * User timeline api rate limit: (872/900)
# * Retrieving nao_sec (nao_sec)'s tweets...
# * Segmenting nao_sec (nao_sec)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (24/205)
# * User timeline api rate limit: (871/900)
# * Retrieving Microsoft MMPC (msftmmpc)'s tweets...
# * Segmenting Microsoft MMPC (msftmmpc)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (25/205)
# * User timeline api rate limit: (870/900)
# * Retrieving herrcore (herrcore)'s tweets...
# * Segmenting herrcore (herrcore)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (26/205)
# * User timeline api rate limit: (869/900)
# * Retrieving Robert McArdle (bobmcardle)'s tweets...
# * Segmenting Robert McArdle (bobmcardle)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (27/205)
# * User timeline api rate limit: (868/900)
# * Retrieving Racco42 (Racco42)'s tweets...
# * Segmenting Racco42 (Racco42)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (28/205)
# * User timeline api rate limit: (867/900)
# * Retrieving Кириакос Экономоу (kyREcon)'s tweets...
# * Segmenting Кириакос Экономоу (kyREcon)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (29/205)
# * User timeline api rate limit: (866/900)
# * Retrieving NCSC UK (ncsc)'s tweets...
# * Segmenting NCSC UK (ncsc)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (30/205)
# * User timeline api rate limit: (865/900)
# * Retrieving Marc Rivero López (Seifreed)'s tweets...
# * Segmenting Marc Rivero López (Seifreed)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (31/205)
# * User timeline api rate limit: (864/900)
# * Retrieving Benkow moʞuƎq (benkow_)'s tweets...
# * Segmenting Benkow moʞuƎq (benkow_)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (32/205)
# * User timeline api rate limit: (863/900)
# * Retrieving LockyBOT (LockyBOT)'s tweets...
# * Segmenting LockyBOT (LockyBOT)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (33/205)
# * User timeline api rate limit: (862/900)
# * Retrieving OD (___OD___)'s tweets...
# * Segmenting OD (___OD___)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (34/205)
# * User timeline api rate limit: (861/900)
# * Retrieving sysopfb (sysopfb)'s tweets...
# * Segmenting sysopfb (sysopfb)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (35/205)
# * User timeline api rate limit: (860/900)
# * Retrieving Patrick Perry (pjbperry)'s tweets...
# * Segmenting Patrick Perry (pjbperry)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (36/205)
# * User timeline api rate limit: (859/900)
# * Retrieving xozyain (xozyain)'s tweets...
# * Segmenting xozyain (xozyain)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (37/205)
# * User timeline api rate limit: (858/900)
# * Retrieving Luis Rocha (countuponsec)'s tweets...
# * Segmenting Luis Rocha (countuponsec)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (38/205)
# * User timeline api rate limit: (857/900)
# * Retrieving Jose Miguel Esparza (EternalTodo)'s tweets...
# * Segmenting Jose Miguel Esparza (EternalTodo)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (39/205)
# * User timeline api rate limit: (856/900)
# * Retrieving x64dbg (x64dbg)'s tweets...
# * Segmenting x64dbg (x64dbg)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (40/205)
# * User timeline api rate limit: (855/900)
# * Retrieving SlavikInfoSec (SlavikInfoSec)'s tweets...
# * Segmenting SlavikInfoSec (SlavikInfoSec)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (41/205)
# * User timeline api rate limit: (854/900)
# * Retrieving FortiGuard Labs (FortiGuardLabs)'s tweets...
# * Segmenting FortiGuard Labs (FortiGuardLabs)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (42/205)
# * User timeline api rate limit: (853/900)
# * Retrieving Antelox (Antelox)'s tweets...
# * Segmenting Antelox (Antelox)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (43/205)
# * User timeline api rate limit: (852/900)
# * Retrieving Malwared (Malwared_)'s tweets...
# * Segmenting Malwared (Malwared_)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (44/205)
# * User timeline api rate limit: (851/900)
# * Retrieving Manuel Caballero (magicmac2000)'s tweets...
# * Segmenting Manuel Caballero (magicmac2000)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (45/205)
# * User timeline api rate limit: (850/900)
# * Retrieving LiveOverflow (LiveOverflow)'s tweets...
# * Segmenting LiveOverflow (LiveOverflow)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (46/205)
# * User timeline api rate limit: (849/900)
# * Retrieving Cyber Maui (BelchSpeak)'s tweets...
# * Segmenting Cyber Maui (BelchSpeak)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (47/205)
# * User timeline api rate limit: (848/900)
# * Retrieving Symantec (symantec)'s tweets...
# * Segmenting Symantec (symantec)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (48/205)
# * User timeline api rate limit: (847/900)
# * Retrieving Malwageddon (Malwageddon)'s tweets...
# * Segmenting Malwageddon (Malwageddon)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (49/205)
# * User timeline api rate limit: (846/900)
# * Retrieving ET Labs (ET_Labs)'s tweets...
# * Segmenting ET Labs (ET_Labs)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (50/205)
# * User timeline api rate limit: (845/900)
# * Retrieving David Montenegro (CryptoInsane)'s tweets...
# * Segmenting David Montenegro (CryptoInsane)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (51/205)
# * User timeline api rate limit: (844/900)
# * Retrieving Matthew Mesa (mesa_matt)'s tweets...
# * Segmenting Matthew Mesa (mesa_matt)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (52/205)
# * User timeline api rate limit: (843/900)
# * Retrieving ききょう (kk_ch1)'s tweets...
# * Segmenting ききょう (kk_ch1)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (53/205)
# * User timeline api rate limit: (842/900)
# * Retrieving JAMESWT (JAMESWT_MHT)'s tweets...
# * Segmenting JAMESWT (JAMESWT_MHT)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (54/205)
# * User timeline api rate limit: (841/900)
# * Retrieving Cuckoo Sandbox (cuckoosandbox)'s tweets...
# * Segmenting Cuckoo Sandbox (cuckoosandbox)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (55/205)
# * User timeline api rate limit: (840/900)
# * Retrieving Jerome Dangu (j_rom_)'s tweets...
# * Segmenting Jerome Dangu (j_rom_)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (56/205)
# * User timeline api rate limit: (839/900)
# * Retrieving ExecuteMalware (executemalware)'s tweets...
# * Segmenting ExecuteMalware (executemalware)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (57/205)
# * User timeline api rate limit: (838/900)
# * Retrieving MalwareHunterTeam (malwrhunterteam)'s tweets...
# * Segmenting MalwareHunterTeam (malwrhunterteam)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (58/205)
# * User timeline api rate limit: (837/900)
# * Retrieving Justin Ragghianti (RagsOTX)'s tweets...
# * Segmenting Justin Ragghianti (RagsOTX)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (59/205)
# * User timeline api rate limit: (836/900)
# * Retrieving StratosphereIPS (StratosphereIPS)'s tweets...
# * Segmenting StratosphereIPS (StratosphereIPS)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (60/205)
# * User timeline api rate limit: (835/900)
# * Retrieving Virus Bulletin (virusbtn)'s tweets...
# * Segmenting Virus Bulletin (virusbtn)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (61/205)
# * User timeline api rate limit: (834/900)
# * Retrieving hasherezade (hasherezade)'s tweets...
# * Segmenting hasherezade (hasherezade)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (62/205)
# * User timeline api rate limit: (833/900)
# * Retrieving edx (criznash)'s tweets...
# * Segmenting edx (criznash)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (63/205)
# * User timeline api rate limit: (832/900)
# * Retrieving Broad Analysis (BroadAnalysis)'s tweets...
# * Segmenting Broad Analysis (BroadAnalysis)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (64/205)
# * User timeline api rate limit: (831/900)
# * Retrieving Bʀʏᴀɴ (bry_campbell)'s tweets...
# * Segmenting Bʀʏᴀɴ (bry_campbell)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (65/205)
# * User timeline api rate limit: (830/900)
# * Retrieving William Metcalf (node5)'s tweets...
# * Segmenting William Metcalf (node5)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (66/205)
# * User timeline api rate limit: (829/900)
# * Retrieving Alęxandęr Hanęl (nullandnull)'s tweets...
# * Segmenting Alęxandęr Hanęl (nullandnull)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (67/205)
# * User timeline api rate limit: (828/900)
# * Retrieving Natata (iNatata)'s tweets...
# * Segmenting Natata (iNatata)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (68/205)
# * User timeline api rate limit: (827/900)
# * Retrieving Piotr Kijewski (piotrkijewski)'s tweets...
# * Segmenting Piotr Kijewski (piotrkijewski)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (69/205)
# * User timeline api rate limit: (826/900)
# * Retrieving TMMalAnalyst (tmmalanalyst)'s tweets...
# * Segmenting TMMalAnalyst (tmmalanalyst)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (70/205)
# * User timeline api rate limit: (825/900)
# * Retrieving News from the Lab (FSLabs)'s tweets...
# * Segmenting News from the Lab (FSLabs)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (71/205)
# * User timeline api rate limit: (824/900)
# * Retrieving Conrad Longmore 🇪🇺 (ConradLongmore)'s tweets...
# * Segmenting Conrad Longmore 🇪🇺 (ConradLongmore)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (72/205)
# * User timeline api rate limit: (823/900)
# * Retrieving torch (TorchML)'s tweets...
# * Segmenting torch (TorchML)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (73/205)
# * User timeline api rate limit: (822/900)
# * Retrieving radare (radareorg)'s tweets...
# * Segmenting radare (radareorg)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (74/205)
# * User timeline api rate limit: (821/900)
# * Retrieving Karsten Hahn (struppigel)'s tweets...
# * Segmenting Karsten Hahn (struppigel)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (75/205)
# * User timeline api rate limit: (820/900)
# * Retrieving REhints (REhints)'s tweets...
# * Segmenting REhints (REhints)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (76/205)
# * User timeline api rate limit: (819/900)
# * Retrieving Dridex BOT (DridexBOT)'s tweets...
# * Segmenting Dridex BOT (DridexBOT)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (77/205)
# * User timeline api rate limit: (818/900)
# * Retrieving codelancer (codelancer)'s tweets...
# * Segmenting codelancer (codelancer)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (78/205)
# * User timeline api rate limit: (817/900)
# * Retrieving R136a1 (TheEnergyStory)'s tweets...
# * Segmenting R136a1 (TheEnergyStory)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (79/205)
# * User timeline api rate limit: (813/900)
# * Retrieving TrendLabs (TrendLabs)'s tweets...
# * Segmenting TrendLabs (TrendLabs)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (80/205)
# * User timeline api rate limit: (809/900)
# * Retrieving Bart (bartblaze)'s tweets...
# * Segmenting Bart (bartblaze)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (81/205)
# * User timeline api rate limit: (805/900)
# * Retrieving briankrebs (briankrebs)'s tweets...
# * Segmenting briankrebs (briankrebs)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (82/205)
# * User timeline api rate limit: (798/900)
# * Retrieving peterkruse (peterkruse)'s tweets...
# * Segmenting peterkruse (peterkruse)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (83/205)
# * User timeline api rate limit: (794/900)
# * Retrieving Santiago Pontiroli (spontiroli)'s tweets...
# * Segmenting Santiago Pontiroli (spontiroli)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (84/205)
# * User timeline api rate limit: (790/900)
# * Retrieving Chris Wakelin (EKwatcher)'s tweets...
# * Segmenting Chris Wakelin (EKwatcher)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (85/205)
# * User timeline api rate limit: (786/900)
# * Retrieving Jake Williams (MalwareJake)'s tweets...
# * Segmenting Jake Williams (MalwareJake)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (86/205)
# * User timeline api rate limit: (781/900)
# * Retrieving Anton Ivanov (antonivanovm)'s tweets...
# * Segmenting Anton Ivanov (antonivanovm)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (87/205)
# * User timeline api rate limit: (775/900)
# * Retrieving malc0de (malc0de)'s tweets...
# * Segmenting malc0de (malc0de)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (88/205)
# * User timeline api rate limit: (760/900)
# * Retrieving The Practical Dev (ThePracticalDev)'s tweets...
# * Segmenting The Practical Dev (ThePracticalDev)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (89/205)
# * User timeline api rate limit: (750/900)
# * Retrieving Clément Lecigne (_clem1)'s tweets...
# * Segmenting Clément Lecigne (_clem1)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (90/205)
# * User timeline api rate limit: (892/900)
# * Retrieving powertool (ithurricanept)'s tweets...
# * Segmenting powertool (ithurricanept)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (91/205)
# * User timeline api rate limit: (884/900)
# * Retrieving Martin Roesler (MartinRoesler)'s tweets...
# * Segmenting Martin Roesler (MartinRoesler)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (92/205)
# * User timeline api rate limit: (880/900)
# * Retrieving Jérôme Segura (jeromesegura)'s tweets...
# * Segmenting Jérôme Segura (jeromesegura)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (93/205)
# * User timeline api rate limit: (865/900)
# * Retrieving DevOps Reactions (devopsreactions)'s tweets...
# * Segmenting DevOps Reactions (devopsreactions)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (94/205)
# * User timeline api rate limit: (859/900)
# * Retrieving Darien Huss (darienhuss)'s tweets...
# * Segmenting Darien Huss (darienhuss)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (95/205)
# * User timeline api rate limit: (854/900)
# * Retrieving Natalie Silvanovich (natashenka)'s tweets...
# * Segmenting Natalie Silvanovich (natashenka)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (96/205)
# * User timeline api rate limit: (849/900)
# * Retrieving Jake Warren (jakewarrentx)'s tweets...
# * Segmenting Jake Warren (jakewarrentx)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (97/205)
# * User timeline api rate limit: (845/900)
# * Retrieving Aels Martin (aelsmartin)'s tweets...
# * Segmenting Aels Martin (aelsmartin)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (98/205)
# * User timeline api rate limit: (840/900)
# * Retrieving Techhelplist (Techhelplistcom)'s tweets...
# * Segmenting Techhelplist (Techhelplistcom)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (99/205)
# * User timeline api rate limit: (834/900)
# * Retrieving hugbomb (hugbomb)'s tweets...
# * Segmenting hugbomb (hugbomb)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (100/205)
# * User timeline api rate limit: (829/900)
# * Retrieving pixiv (pixiv)'s tweets...
# * Segmenting pixiv (pixiv)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (101/205)
# * User timeline api rate limit: (820/900)
# * Retrieving Brad (malware_traffic)'s tweets...
# * Segmenting Brad (malware_traffic)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (102/205)
# * User timeline api rate limit: (819/900)
# * Retrieving Kyle Wilhoit (lowcalspam)'s tweets...
# * Segmenting Kyle Wilhoit (lowcalspam)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (103/205)
# * User timeline api rate limit: (818/900)
# * Retrieving 濵田譲治 (JojiHamada)'s tweets...
# * Segmenting 濵田譲治 (JojiHamada)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (104/205)
# * User timeline api rate limit: (817/900)
# * Retrieving webDEViL (w3bd3vil)'s tweets...
# * Segmenting webDEViL (w3bd3vil)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (105/205)
# * User timeline api rate limit: (816/900)
# * Retrieving Ivan Fratric (ifsecure)'s tweets...
# * Segmenting Ivan Fratric (ifsecure)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (106/205)
# * User timeline api rate limit: (815/900)
# * Retrieving Roberto Martinez (robemtnez)'s tweets...
# * Segmenting Roberto Martinez (robemtnez)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (107/205)
# * User timeline api rate limit: (814/900)
# * Retrieving Octave Klaba / Oles (olesovhcom)'s tweets...
# * Segmenting Octave Klaba / Oles (olesovhcom)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (108/205)
# * User timeline api rate limit: (813/900)
# * Retrieving Threatglass (threatglass)'s tweets...
# * Segmenting Threatglass (threatglass)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (109/205)
# * User timeline api rate limit: (812/900)
# * Retrieving Peter Pi (heisecode)'s tweets...
# * Segmenting Peter Pi (heisecode)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (110/205)
# * User timeline api rate limit: (811/900)
# * Retrieving Jack (malwareforme)'s tweets...
# * Segmenting Jack (malwareforme)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (111/205)
# * User timeline api rate limit: (810/900)
# * Retrieving Snort 🐷 (Snort)'s tweets...
# * Segmenting Snort 🐷 (Snort)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (112/205)
# * User timeline api rate limit: (809/900)
# * Retrieving brooks_li (brooks_li)'s tweets...
# * Segmenting brooks_li (brooks_li)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (113/205)
# * User timeline api rate limit: (808/900)
# * Retrieving Timo Hirvonen (TimoHirvonen)'s tweets...
# * Segmenting Timo Hirvonen (TimoHirvonen)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (114/205)
# * User timeline api rate limit: (807/900)
# * Retrieving Alexandru Maximciuc (amaximciuc)'s tweets...
# * Segmenting Alexandru Maximciuc (amaximciuc)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (115/205)
# * User timeline api rate limit: (806/900)
# * Retrieving ExploitKitsMustDie (EkMustDie)'s tweets...
# * Segmenting ExploitKitsMustDie (EkMustDie)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (116/205)
# * User timeline api rate limit: (805/900)
# * Retrieving Malekal's site (malekal_morte)'s tweets...
# * Segmenting Malekal's site (malekal_morte)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (117/205)
# * User timeline api rate limit: (804/900)
# * Retrieving Anonymous (AnonymousGlobo)'s tweets...
# * Segmenting Anonymous (AnonymousGlobo)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (118/205)
# * User timeline api rate limit: (803/900)
# * Retrieving Yonathan Klijnsma (ydklijnsma)'s tweets...
# * Segmenting Yonathan Klijnsma (ydklijnsma)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (119/205)
# * User timeline api rate limit: (802/900)
# * Retrieving Reid Wiseman (astro_reid)'s tweets...
# * Segmenting Reid Wiseman (astro_reid)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (120/205)
# * User timeline api rate limit: (801/900)
# * Retrieving MileHighSocalClub (__MHSC)'s tweets...
# * Segmenting MileHighSocalClub (__MHSC)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (121/205)
# * User timeline api rate limit: (800/900)
# * Retrieving refeia (refeia)'s tweets...
# * Segmenting refeia (refeia)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (122/205)
# * User timeline api rate limit: (799/900)
# * Retrieving Mike Bostock (mbostock)'s tweets...
# * Segmenting Mike Bostock (mbostock)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (123/205)
# * User timeline api rate limit: (798/900)
# * Retrieving Frank Denis (jedisct1)'s tweets...
# * Segmenting Frank Denis (jedisct1)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (124/205)
# * User timeline api rate limit: (797/900)
# * Retrieving カワタヒサシ (kawata_hisashi)'s tweets...
# * Segmenting カワタヒサシ (kawata_hisashi)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (125/205)
# * User timeline api rate limit: (796/900)
# * Retrieving Travis Oliphant (teoliphant)'s tweets...
# * Segmenting Travis Oliphant (teoliphant)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (126/205)
# * User timeline api rate limit: (795/900)
# * Retrieving Fernando Perez (fperez_org)'s tweets...
# * Segmenting Fernando Perez (fperez_org)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (127/205)
# * User timeline api rate limit: (794/900)
# * Retrieving Wes McKinney (wesmckinn)'s tweets...
# * Segmenting Wes McKinney (wesmckinn)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (128/205)
# * User timeline api rate limit: (793/900)
# * Retrieving FBI (FBI)'s tweets...
# * Segmenting FBI (FBI)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (129/205)
# * User timeline api rate limit: (792/900)
# * Retrieving Neutral8✗9eR (0x009AD6_810)'s tweets...
# * Segmenting Neutral8✗9eR (0x009AD6_810)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (130/205)
# * User timeline api rate limit: (790/900)
# * Retrieving Jessica McKellar (jessicamckellar)'s tweets...
# * Segmenting Jessica McKellar (jessicamckellar)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (131/205)
# * User timeline api rate limit: (784/900)
# * Retrieving wu shi (team509)'s tweets...
# * Segmenting wu shi (team509)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (132/205)
# * User timeline api rate limit: (780/900)
# * Retrieving KEENLAB (keen_lab)'s tweets...
# * Segmenting KEENLAB (keen_lab)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (133/205)
# * User timeline api rate limit: (772/900)
# * Retrieving Yuki Chen (guhe120)'s tweets...
# * Segmenting Yuki Chen (guhe120)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (134/205)
# * User timeline api rate limit: (768/900)
# * Retrieving PhysicalDrive0 (PhysicalDrive0)'s tweets...
# * Segmenting PhysicalDrive0 (PhysicalDrive0)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (135/205)
# * User timeline api rate limit: (762/900)
# * Retrieving Angelo Dell'Aera (angelodellaera)'s tweets...
# * Segmenting Angelo Dell'Aera (angelodellaera)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (136/205)
# * User timeline api rate limit: (758/900)
# * Retrieving João Gouveia (jgouv)'s tweets...
# * Segmenting João Gouveia (jgouv)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (137/205)
# * User timeline api rate limit: (752/900)
# * Retrieving Dhia Mahjoub (DhiaLite)'s tweets...
# * Segmenting Dhia Mahjoub (DhiaLite)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (138/205)
# * User timeline api rate limit: (747/900)
# * Retrieving FireF0X (hFireF0X)'s tweets...
# * Segmenting FireF0X (hFireF0X)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (139/205)
# * User timeline api rate limit: (738/900)
# * Retrieving Artem I. Baranov (artem_i_baranov)'s tweets...
# * Segmenting Artem I. Baranov (artem_i_baranov)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (140/205)
# * User timeline api rate limit: (723/900)
# * Retrieving Artem I. Baranov (artem_i_baranov)'s tweets...
# * Segmenting Artem I. Baranov (artem_i_baranov)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (141/205)
# * User timeline api rate limit: (718/900)
# * Retrieving TwitPic (TwitPic)'s tweets...
# * Segmenting TwitPic (TwitPic)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (142/205)
# * User timeline api rate limit: (714/900)
# * Retrieving Xylitol (Xylit0l)'s tweets...
# * Segmenting Xylitol (Xylit0l)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (143/205)
# * User timeline api rate limit: (709/900)
# * Retrieving Kafeine (kafeine)'s tweets...
# * Segmenting Kafeine (kafeine)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (144/205)
# * User timeline api rate limit: (704/900)
# * Retrieving Andrej Karpathy (karpathy)'s tweets...
# * Segmenting Andrej Karpathy (karpathy)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (145/205)
# * User timeline api rate limit: (700/900)
# * Retrieving Ian Goodfellow (goodfellow_ian)'s tweets...
# * Segmenting Ian Goodfellow (goodfellow_ian)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (146/205)
# * User timeline api rate limit: (695/900)
# * Retrieving Hugo Larochelle (hugo_larochelle)'s tweets...
# * Segmenting Hugo Larochelle (hugo_larochelle)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (147/205)
# * User timeline api rate limit: (691/900)
# * Retrieving Oriol Vinyals (OriolVinyalsML)'s tweets...
# * Segmenting Oriol Vinyals (OriolVinyalsML)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (148/205)
# * User timeline api rate limit: (687/900)
# * Retrieving Soumith Chintala (soumithchintala)'s tweets...
# * Segmenting Soumith Chintala (soumithchintala)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (149/205)
# * User timeline api rate limit: (682/900)
# * Retrieving Fei-Fei Li (drfeifei)'s tweets...
# * Segmenting Fei-Fei Li (drfeifei)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (150/205)
# * User timeline api rate limit: (678/900)
# * Retrieving Russ Salakhutdinov (rsalakhu)'s tweets...
# * Segmenting Russ Salakhutdinov (rsalakhu)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (151/205)
# * User timeline api rate limit: (673/900)
# * Retrieving Richard (RichardSocher)'s tweets...
# * Segmenting Richard (RichardSocher)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (152/205)
# * User timeline api rate limit: (670/900)
# * Retrieving Christopher Manning (chrmanning)'s tweets...
# * Segmenting Christopher Manning (chrmanning)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (153/205)
# * User timeline api rate limit: (664/900)
# * Retrieving Stanford NLP Group (stanfordnlp)'s tweets...
# * Segmenting Stanford NLP Group (stanfordnlp)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (154/205)
# * User timeline api rate limit: (658/900)
# * Retrieving Nando de Freitas (NandoDF)'s tweets...
# * Segmenting Nando de Freitas (NandoDF)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (155/205)
# * User timeline api rate limit: (654/900)
# * Retrieving ML @ REDDIT (mxlearn)'s tweets...
# * Segmenting ML @ REDDIT (mxlearn)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (156/205)
# * User timeline api rate limit: (650/900)
# * Retrieving Kaggle (kaggle)'s tweets...
# * Segmenting Kaggle (kaggle)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (157/205)
# * User timeline api rate limit: (643/900)
# * Retrieving Denny Britz (dennybritz)'s tweets...
# * Segmenting Denny Britz (dennybritz)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (158/205)
# * User timeline api rate limit: (637/900)
# * Retrieving Kyunghyun Cho (kchonyc)'s tweets...
# * Segmenting Kyunghyun Cho (kchonyc)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (159/205)
# * User timeline api rate limit: (633/900)
# * Retrieving Thang Luong (lmthang)'s tweets...
# * Segmenting Thang Luong (lmthang)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (160/205)
# * User timeline api rate limit: (625/900)
# * Retrieving DeepMind (DeepMindAI)'s tweets...
# * Segmenting DeepMind (DeepMindAI)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (161/205)
# * User timeline api rate limit: (621/900)
# * Retrieving distillpub (distillpub)'s tweets...
# * Segmenting distillpub (distillpub)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (162/205)
# * User timeline api rate limit: (620/900)
# * Retrieving Google Research (googleresearch)'s tweets...
# * Segmenting Google Research (googleresearch)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (163/205)
# * User timeline api rate limit: (619/900)
# * Retrieving TensorFlow Community (TensorFlo)'s tweets...
# * Segmenting TensorFlow Community (TensorFlo)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (164/205)
# * User timeline api rate limit: (618/900)
# * Retrieving Sundar Pichai (sundarpichai)'s tweets...
# * Segmenting Sundar Pichai (sundarpichai)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (165/205)
# * User timeline api rate limit: (617/900)
# * Retrieving Mustafa Suleyman (mustafasuleymn)'s tweets...
# * Segmenting Mustafa Suleyman (mustafasuleymn)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (166/205)
# * User timeline api rate limit: (607/900)
# * Retrieving Google (Google)'s tweets...
# * Segmenting Google (Google)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (167/205)
# * User timeline api rate limit: (601/900)
# * Retrieving Demis Hassabis (demishassabis)'s tweets...
# * Segmenting Demis Hassabis (demishassabis)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (168/205)
# * User timeline api rate limit: (597/900)
# * Retrieving Bill Gates (BillGates)'s tweets...
# * Segmenting Bill Gates (BillGates)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (169/205)
# * User timeline api rate limit: (592/900)
# * Retrieving Yann LeCun (ylecun)'s tweets...
# * Segmenting Yann LeCun (ylecun)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (170/205)
# * User timeline api rate limit: (586/900)
# * Retrieving Elon Musk (elonmusk)'s tweets...
# * Segmenting Elon Musk (elonmusk)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (171/205)
# * User timeline api rate limit: (578/900)
# * Retrieving Deep Learning Hub (DeepLearningHub)'s tweets...
# * Segmenting Deep Learning Hub (DeepLearningHub)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (172/205)
# * User timeline api rate limit: (571/900)
# * Retrieving hardmaru (hardmaru)'s tweets...
# * Segmenting hardmaru (hardmaru)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (173/205)
# * User timeline api rate limit: (568/900)
# * Retrieving Andrew Ng (AndrewYNg)'s tweets...
# * Segmenting Andrew Ng (AndrewYNg)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (174/205)
# * User timeline api rate limit: (563/900)
# * Retrieving François Chollet (fchollet)'s tweets...
# * Segmenting François Chollet (fchollet)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# Rate limit reached. Sleeping for: 159
# * Process: (175/205)
# * User timeline api rate limit: (460/900)
# * Retrieving OpenAI (OpenAI)'s tweets...
# * Segmenting OpenAI (OpenAI)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (176/205)
# * User timeline api rate limit: (459/900)
# * Retrieving Gabriel Synnaeve 📎 (syhw)'s tweets...
# * Segmenting Gabriel Synnaeve 📎 (syhw)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (177/205)
# * User timeline api rate limit: (458/900)
# * Retrieving Microsoft Research (MSFTResearch)'s tweets...
# * Segmenting Microsoft Research (MSFTResearch)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (178/205)
# * User timeline api rate limit: (457/900)
# * Retrieving Sebastian Thrun (SebastianThrun)'s tweets...
# * Segmenting Sebastian Thrun (SebastianThrun)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (179/205)
# * User timeline api rate limit: (456/900)
# * Retrieving NIPS (NipsConference)'s tweets...
# * Segmenting NIPS (NipsConference)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (180/205)
# * User timeline api rate limit: (455/900)
# * Retrieving Radim Řehůřek (RadimRehurek)'s tweets...
# * Segmenting Radim Řehůřek (RadimRehurek)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (181/205)
# * User timeline api rate limit: (454/900)
# * Retrieving Yarin (yaringal)'s tweets...
# * Segmenting Yarin (yaringal)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (182/205)
# * User timeline api rate limit: (451/900)
# * Retrieving lisha li (lishali88)'s tweets...
# * Segmenting lisha li (lishali88)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (183/205)
# * User timeline api rate limit: (450/900)
# * Retrieving Caiming Xiong (CaimingXiong)'s tweets...
# * Segmenting Caiming Xiong (CaimingXiong)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (184/205)
# * User timeline api rate limit: (449/900)
# * Retrieving Matthew Honnibal (honnibal)'s tweets...
# * Segmenting Matthew Honnibal (honnibal)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (185/205)
# * User timeline api rate limit: (448/900)
# * Retrieving TensorFlow (tensorflow)'s tweets...
# * Segmenting TensorFlow (tensorflow)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (186/205)
# * User timeline api rate limit: (447/900)
# * Retrieving Google Brain (GoogleBrain)'s tweets...
# * Segmenting Google Brain (GoogleBrain)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (187/205)
# * User timeline api rate limit: (446/900)
# * Retrieving (((λ()(λ() 'yoav)))) (yoavgo)'s tweets...
# * Segmenting (((λ()(λ() 'yoav)))) (yoavgo)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (188/205)
# * User timeline api rate limit: (445/900)
# * Retrieving CSAIL at MIT (MIT_CSAIL)'s tweets...
# * Segmenting CSAIL at MIT (MIT_CSAIL)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (189/205)
# * User timeline api rate limit: (444/900)
# * Retrieving Shao-Hua Sun (shaohua0116)'s tweets...
# * Segmenting Shao-Hua Sun (shaohua0116)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (190/205)
# * User timeline api rate limit: (443/900)
# * Retrieving Chris Olah (ch402)'s tweets...
# * Segmenting Chris Olah (ch402)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (191/205)
# * User timeline api rate limit: (442/900)
# * Retrieving Greg Brockman (gdb)'s tweets...
# * Segmenting Greg Brockman (gdb)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (192/205)
# * User timeline api rate limit: (441/900)
# * Retrieving Baidu Research (BaiduResearch)'s tweets...
# * Segmenting Baidu Research (BaiduResearch)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (193/205)
# * User timeline api rate limit: (440/900)
# * Retrieving arXiv CS-CL (arxiv_cscl)'s tweets...
# * Segmenting arXiv CS-CL (arxiv_cscl)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (194/205)
# * User timeline api rate limit: (439/900)
# * Retrieving harvardnlp (harvardnlp)'s tweets...
# * Segmenting harvardnlp (harvardnlp)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (195/205)
# * User timeline api rate limit: (438/900)
# * Retrieving Alexander R Johansen (AlexRoseJo)'s tweets...
# * Segmenting Alexander R Johansen (AlexRoseJo)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (196/205)
# * User timeline api rate limit: (437/900)
# * Retrieving YenChenLin (yen_chen_lin)'s tweets...
# * Segmenting YenChenLin (yen_chen_lin)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (197/205)
# * User timeline api rate limit: (434/900)
# * Retrieving michael_nielsen (michael_nielsen)'s tweets...
# * Segmenting michael_nielsen (michael_nielsen)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (198/205)
# * User timeline api rate limit: (433/900)
# * Retrieving Terry Taewoong Um (TerryUm_ML)'s tweets...
# * Segmenting Terry Taewoong Um (TerryUm_ML)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (199/205)
# * User timeline api rate limit: (432/900)
# * Retrieving shanjtwit (shanjabberwocky)'s tweets...
# * Segmenting shanjtwit (shanjabberwocky)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (200/205)
# * User timeline api rate limit: (431/900)
# * Retrieving Gensim (gensim_py)'s tweets...
# * Segmenting Gensim (gensim_py)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (201/205)
# * User timeline api rate limit: (428/900)
# * Retrieving RaRe Technologies (RaReTechTeam)'s tweets...
# * Segmenting RaRe Technologies (RaReTechTeam)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (202/205)
# * User timeline api rate limit: (427/900)
# * Retrieving /MachineLearning (slashML)'s tweets...
# * Segmenting /MachineLearning (slashML)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (203/205)
# * User timeline api rate limit: (426/900)
# * Retrieving spark (spark68845621)'s tweets...
# * Segmenting spark (spark68845621)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# * Process: (204/205)
# * User timeline api rate limit: (425/900)
# * Retrieving HubertLin (HubertLin8787)'s tweets...
# * Segmenting HubertLin (HubertLin8787)'s tweets by date...
# --------------------------------------------------------------------------------------------------------------------
# CPU times: user 25.4 s, sys: 3.27 s, total: 28.7 s
# Wall time: 16min 20s

# %%
def save_friends_tweets(friends_tweets):

    for friend in friends:
        
        tweets_keyed_by_date = friends_tweets.get(friend.screen_name, None)
        
        if tweets_keyed_by_date is None:
            continue
    
        # Make folder for friends
        friend_folder_path = os.path.join(dataset_folder_path, friend.screen_name)
        if not os.path.exists(friend_folder_path):
            os.makedirs(friend_folder_path)
        
        print('* Saving {} ({})\'s tweets...'.format(friend.name, friend.screen_name))
        
        for date, tweets in tweets_keyed_by_date.items():
            # Save to pickle
            tweets_file_path = os.path.join(friend_folder_path, '{}.pkl'.format(date)) 
            with open(tweets_file_path, 'wb') as f:
                # print('  - Writing to {} tweets to "{}"...'.format(len(tweets), tweets_file_path))
                pickle.dump(tweets, f)

        print('-'*116)

save_friends_tweets(friends_tweets)
# Out:
# * Saving Han Xiao (TerryUm_ML)'s tweets...
#   - Writing to 1 tweets to "dataset/twitter/hxiao/
pkl"...
#   - Writing to 3 tweets to "dataset/twitter/slashML/2017-07-08.pkl"...
#   - Writing to 4 tweets to "dataset/twitter/slashML/2017-06-28.pkl"...
#   - Writing to 8 tweets to "dataset/twitter/slashML/2017-06-27.pkl"...
#   - Writing to 5 tweets to "dataset/twitter/slashML/2017-06-26.pkl"...
#   - Writing to 9 tweets to "dataset/twitter/slashML/2017-06-25.pkl"...
#   - Writing to 6 tweets to "dataset/twitter/slashML/2017-06-24.pkl"...
#   - Writing to 12 tweets to "dataset/twitter/slashML/2017-06-23.pkl"...
#   - Writing to 8 tweets to "dataset/twitter/slashML/2017-06-22.pkl"...
#   - Writing to 5 tweets to "dataset/twitter/slashML/2017-06-12.pkl"...
#   - Writing to 7 tweets to "dataset/twitter/slashML/2017-06-11.pkl"...
#   - Writing to 7 tweets to "dataset/twitter/slashML/2017-06-10.pkl"...
#   - Writing to 5 tweets to "dataset/twitter/slashML/2017-06-09.pkl"...
#   - Writing to 8 tweets to "dataset/twitter/slashML/2017-06-08.pkl"...
#   - Writing to 8 tweets to "dataset/twitter/slashML/2017-06-07.pkl"...
#   - Writing to 5 tweets to "dataset/twitter/slashML/2017-06-06.pkl"...
#   - Writing to 7 tweets to "dataset/twitter/slashML/2017-06-05.pkl"...
#   - Writing to 5 tweets to "dataset/twitter/slashML/2017-06-04.pkl"...
#   - Writing to 2 tweets to "dataset/twitter/slashML/2017-06-01.pkl"...
#   - Writing to 9 tweets to "dataset/twitter/slashML/2017-05-31.pkl"...
#   - Writing to 9 tweets to "dataset/twitter/slashML/2017-05-30.pkl"...
#   - Writing to 8 tweets to "dataset/twitter/slashML/2017-05-29.pkl"...
#   - Writing to 3 tweets to "dataset/twitter/slashML/2017-05-28.pkl"...
#   - Writing to 6 tweets to "dataset/twitter/slashML/2017-05-27.pkl"...
#   - Writing to 8 tweets to "dataset/twitter/slashML/2017-05-26.pkl"...
#   - Writing to 10 tweets to "dataset/twitter/slashML/2017-05-25.pkl"...
#   - Writing to 9 tweets to "dataset/twitter/slashML/2017-05-24.pkl"...
#   - Writing to 2 tweets to "dataset/twitter/slashML/2017-05-22.pkl"...
#   - Writing to 3 tweets to "dataset/twitter/slashML/2017-05-21.pkl"...
# --------------------------------------------------------------------------------------------------------------------
# * Saving spark (TerryUm_ML)'s tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Saving HubertLin (TerryUm_ML)'s tweets...
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Read pickle files and restore tweets

# %%
def restore_friends_tweets():

    friends_tweets = {screen_name: {} for screen_name in os.listdir(dataset_folder_path)}

    for screen_name in list(friends_tweets.keys()):
        
        print('* Restoring {}\'s tweets...'.format(screen_name))
        
        friend_folder_path = os.path.join(dataset_folder_path, screen_name)
            
        for file_name in os.listdir(friend_folder_path):
            # Read pickle, i.e. tweets_keyed_by_date
            tweets_file_path = os.path.join(friend_folder_path, file_name)
            
            with open(tweets_file_path, 'rb') as f:
                # print('* Reading tweets from "{}"...'.format(tweets_file_path))
                date = file_name.split('.')[0]
                friends_tweets[screen_name][date] = pickle.load(f)
                
        print('-'*116)
        
    return friends_tweets

friends_tweets = restore_friends_tweets()
# Out:
# * Restoring 0x009AD6_810's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring 0xD09AD0BED182's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring ___OD___'s tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring __MHSC's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring _clem1's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring aelsmartin's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring AlexRoseJo's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring amaximciuc's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring AndrewYNg's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring angelodellaera's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring AnonymousGlobo's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring Antelox's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring antonivanovm's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring ApacheSpark's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring artem_i_baranov's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring arxiv_cscl's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring astro_reid's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Resto
tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring w3bd3vil's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring wesmckinn's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring x64dbg's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring x9090's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring xozyain's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring Xylit0l's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring yaringal's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring ydklijnsma's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring yen_chen_lin's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring ylecun's tweets...
# --------------------------------------------------------------------------------------------------------------------
# * Restoring yoavgo's tweets...
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Test if restore successfully

# %%
friends_tweets['TerryUm_ML'].keys()
# Out:
# dict_keys(['2017-06-05', '2017-06-06', '2017-06-08', '2017-06-09', '2017-06-10', '2017-06-11', '2017-06-12', '2017-06-13', '2017-06-15', '2017-06-16', '2017-06-17', '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-25', '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29', '2017-06-30', '2017-07-01', '2017-07-02', '2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07', '2017-07-09', '2017-07-10'])

# %%
""" Test if we restore tweets successfully """
for tweet in friends_tweets['TerryUm_ML']['2017-07-10']:
    print_tweet(tweet)
# Out:
# * created_at: 2017-07-10 21:37:37
# * id: 884527052652720128
# * lang: en
# * user name: Terry Taewoong Um
# * user screen name: TerryUm_ML
# * user profile url: https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg
# * favorite_count: 19
# * retweet count: 7
# * text: "An overview of gradient descent optimization algorithms": SGD, Adagrad, Adadelta, RMSprop, Adam, etc.… https://t.co/oX4XrECpj8
# * hashtags: []
# * symbols: []
# * urls: [{'url': 'https://t.co/oX4XrECpj8', 'expanded_url': 'https://twitter.com/i/web/status/884527052652720128', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [104, 127]}]
# * user_mentions: []
# --------------------------------------------------------------------------------------------------------------------
# * created_at: 2017-07-10 21:30:32
# * id: 884525268278398979
# * lang: en
# * user name: Terry Taewoong Um
# * user screen name: TerryUm_ML
# * user profile url: https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg
# * favorite_count: 2
# * retweet count: 0
# * text: "Emergence of Locomotion Behaviours in Rich Environments" by DeepMind https://t.co/W0QCjpWGgN https://t.co/WXw5uRTTv8
# * hashtags: []
# * symbols: []
# * urls: [{'url': 'https://t.co/W0QCjpWGgN', 'expanded_url': 'https://arxiv.org/abs/1707.02286', 'display_url': 'arxiv.org/abs/1707.02286', 'indices': [70, 93]}, {'url': 'https://t.co/WXw5uRTTv8', 'expanded_url': 'https://twitter.com/OriolVinyalsML/status/884328832320368644', 'display_url': 'twitter.com/OriolVinyalsML…', 'indices': [94, 117]}]
# * user_mentions: []
# --------------------------------------------------------------------------------------------------------------------
# * created_at: 2017-07-10 05:39:29
# * id: 884285929510363136
# * lang: en
# * user name: Terry Taewoong Um
# * user screen name: TerryUm_ML
# * user profile url: https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg
# * favorite_count: 35
# * retweet count: 3
# * text: "A Nested Attention Neural Hybrid Model for Grammatical Error Correction" by MS: correct both characters and words… https://t.co/NGPKXbuY75
# * hashtags: []
# * symbols: []
# * urls: [{'url': 'https://t.co/NGPKXbuY75', 'expanded_url': 'https://twitter.com/i/web/status/884285929510363136', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [116, 139]}]
# * user_mentions: []
# --------------------------------------------------------------------------------------------------------------------
# * created_at: 2017-07-10 05:37:19
# * id: 884285384833814528
# * lang: en
# * user name: Terry Taewoong Um
# * user screen name: TerryUm_ML
# * user profile url: https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg
# * favorite_count: 16
# * retweet count: 4
# * text: "Learning Loss Functions for Semi-supervised Learning via Discriminative Adversarial Networks": use 2 discriminator… https://t.co/794qaiGmzE
# * hashtags: []
# * symbols: []
# * urls: [{'url': 'https://t.co/794qaiGmzE', 'expanded_url': 'https://twitter.com/i/web/status/884285384833814528', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [117, 140]}]
# * user_mentions: []
# --------------------------------------------------------------------------------------------------------------------
# * created_at: 2017-07-10 05:27:53
# * id: 884283009016496128
# * lang: en
# * user name: Terry Taewoong Um
# * user screen name: TerryUm_ML
# * user profile url: https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg
# * favorite_count: 10
# * retweet count: 7
# * text: "Emergence of Locomotion Behaviours in Rich Environments" by DeepMind: run, jump, crouch w/ forward-progress reward… https://t.co/Hm5vWvXZcq
# * hashtags: []
# * symbols: []
# * urls: [{'url': 'https://t.co/Hm5vWvXZcq', 'expanded_url': 'https://twitter.com/i/web/status/884283009016496128', 'display_url': 'twitter.com/i/web/status/8…', 'indices': [117, 140]}]
# * user_mentions: []
# --------------------------------------------------------------------------------------------------------------------
# * created_at: 2017-07-10 04:59:28
# * id: 884275857816244224
# * lang: ko
# * user name: Terry Taewoong Um
# * user screen name: TerryUm_ML
# * user profile url: https://pbs.twimg.com/profile_images/839986509767954437/wGy9rI9c_normal.jpg
# * favorite_count: 0
# * retweet count: 0
# * text: @d_ijk_stra 15년전 얘기라면, 우리로 따지면 87학번이 이야기하는 셈...(...)
# * hashtags: []
# * symbols: []
# * urls: []
# * user_mentions: [{'screen_name': 'd_ijk_stra', 'name': '어엉부엉', 'id': 18507361, 'id_str': '18507361', 'indices': [0, 11]}]
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Check API Rate Limit Status
# - Rate limit table: https://dev.twitter.com/rest/public/rate-limits

# %%
rate_limit_status = api.rate_limit_status()

print('friends:')
print('limit', rate_limit_status['resources']['friends']['/friends/list']['limit'])
print('remaining', rate_limit_status['resources']['friends']['/friends/list']['remaining'])
print('reset', time.ctime(rate_limit_status['resources']['friends']['/friends/list']['reset']))
print()
print('user timeline:')
print('limit', rate_limit_status['resources']['statuses']['/statuses/user_timeline']['limit'])
print('remaining', rate_limit_status['resources']['statuses']['/statuses/user_timeline']['remaining'])
print('reset', time.ctime(rate_limit_status['resources']['statuses']['/statuses/user_timeline']['reset']))
# Out:
# friends:
# limit 15
# remaining 0
# reset Sun Jul 16 15:13:38 2017
#
# user timeline:
# limit 900
# remaining 860
# reset Sun Jul 16 15:13:40 2017
